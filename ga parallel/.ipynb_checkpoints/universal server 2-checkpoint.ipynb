# %%
import socket, pickle

# %% [markdown]
# HOST = '192.168.43.121'
# PORT1 = 5000
# ss1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ss1.bind((HOST, PORT1))
# ss1.listen(100)
# HOST = '192.168.43.121'
# PORT1 = 5001
# sr1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# sr1.bind((HOST, PORT1))
# sr1.listen(100)

# %% [markdown]
# HOST = '127.0.0.1'
# PORT1 = 5008
# s1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# s1.bind((HOST, PORT1))
# s1.listen(5)

# %%
HOST = '192.168.43.193'
PORT1 = 5004
ss1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
ss1.bind((HOST, PORT1))
ss1.listen(100)
HOST = '192.168.43.193'
PORT1 = 5005
sr1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sr1.bind((HOST, PORT1))
sr1.listen(100)

# %%
HOST = '192.168.43.193'
PORT1 = 5006
ss2 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
ss2.bind((HOST, PORT1))
ss2.listen(100)
HOST = '192.168.43.193'
PORT1 = 5007
sr2 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sr2.bind((HOST, PORT1))
sr2.listen(100)

# %%
def sends(s,variable):
    
    c, addr = s.accept()      
    print ('Got connection from', addr)
    #variable = [ProcessData() for i in range(10000)]
    # Pickle the object and send it to the server
    #data_string = pickle.dumps(variable)
    c.send(variable) 
    c.close()
    s.listen(1)
def recs(s):
    c, addr = s.accept()
    print ('Connected by', addr)
    data = c.recv(2048)
    #data_variable = pickle.loads(data)
    c.close()
    s.listen(1)
    return data

# %%
while True:
    print("phase1")
    msgc1=recs(ss1)
    print("phase2")
    msgc2=recs(ss2)
    print("phase3")
    sends(sr1,msgc2)
    print("phase4")
    sends(sr2,msgc1)
    print("phase5")
# Out:
# phase1
# Connected by ('192.168.43.193', 50149)
# phase2
# Connected by ('192.168.43.5', 62781)
# phase3
# Got connection from ('192.168.43.193', 50150)
# phase4
# Got connection from ('192.168.43.5', 62782)
# phase5
# phase1
# Connected by ('192.168.43.193', 50413)
# phase2
# Connected by ('192.168.43.5', 62783)
# phase3
# Got connection from ('192.168.43.193', 50414)
# phase4
# Got connection from ('192.168.43.5', 62784)
# phase5
# phase1
# Connected by ('192.168.43.193', 50418)
# phase2
# Connected by ('192.168.43.5', 62785)
# phase3
# Got connection from ('192.168.43.193', 50420)
# phase4
# Got connection from ('192.168.43.5', 62786)
# phase5
# phase1
# Connected by ('192.168.43.193', 50429)
# phase2
# Connected by ('192.168.43.5', 62787)
# phase3
# Got connection from ('192.168.43.193', 50438)
# phase4
# Got connection from ('192.168.43.5', 62788)
# phase5
# phase1
# Connected by ('192.168.43.193', 50439)
# phase2
# Connected by ('192.168.43.5', 62789)
# phase3
# ...

# %%
print("phase1")
msgc1=recs(s1)
print("phase2")
msgc2=recs(s2)
print("phase3")
sends(s1,msgc2)
print("phase4")
sends(s2,msgc1)
print("phase5")
# Out:
# phase1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9040d0b2cd29> in <module>
#       1 print("phase1")
# ----> 2 msgc1=recs(s1)
#       3 print("phase2")
#       4 msgc2=recs(s2)
#       5 print("phase3")
#
# NameError: name 'recs' is not defined

# %%
s1.close()
s2.close()
