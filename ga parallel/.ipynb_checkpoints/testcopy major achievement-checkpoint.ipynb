# %%
from numpy.random import rand
import numpy as np
from IPython.display import clear_output
from IPython.display import Markdown, display
import socket, pickle

# %% [markdown]
# 1.for inheritance in python
#  class subclass(superclass name)
# 2.accessing class methonds through objects then need to add self as a method parameter
# just only for methods that needed to be accessed through outside / by objects

# %%
import multiprocessing
from multiprocessing import Process as mp
multiprocessing.cpu_count()
# Out:
# 12

# %%
#del(pop)
import gc
gc.collect()
# Out:
# 82

# %%
ele_list="ABCDEFGHIJKLMNOPQRSTUVWXYZ  "
target="ALPHA CODE X LOAD TEST MAGIC K"
#target="ABCDE"
tlen=len(target)
tlen
min_fitness_val=4
#print(dnac(25))

# %%
def gfitness_cal(dna):
    f = 0
    for i in range(tlen):
        if (target[i] == dna[i]):
            f =f + 1
    return f

# %%
class gene_func:

    def to_char(self, x):
        return ele_list[x]

    def dnac(self):
        return ''.join(list(map(self.to_char, list(map(int, rand(tlen)*27)))))

class gene(gene_func):

    #fitness calculation function
    def fitness_cal(self):
        f = 0
        for i in range(tlen):
            if (target[i] == self.dna[i]):
                f =f + 1
            
        return f


    
    #manulaly create a DNA 
    def __init__(self,st=None,fit=None):
        if st==None:    
            self.dna = self.dnac()
        else:    
            self.dna = st
        if fit==None:    
            self.fit = self.fitness_cal()
        else:
            self.fit=fit
        
    #DNA mutation
    def mutation(self):
        pass
    
    #function for crossover
    def cross_over(self):
        pass

# %%
"""def sendc(obj,HOST="192.168.43.121",PORT=5002):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect((HOST, PORT))  
    variable = [obj for i in range(10000)]
    #variable = [ProcessData() for i in range(10000)]
    # Pickle the object and send it to the server
    data_string = pickle.dumps(variable)
    s.send(data_string) 
def recc(HOST="192.168.43.121",PORT=5002):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect((HOST, PORT))
    data = s.recv(100000)
    data_variable = pickle.loads(data)
    return(data_variable)"""
def sendc(msg,HOST="192.168.43.21",PORT=5004 ):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect((HOST, PORT))  
    s.send(msg.encode('utf-8'))
def recc(HOST="192.168.43.21",PORT=5005):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect((HOST, PORT))
    msg = s.recv(2048).decode("utf-8")
    #print(msg)
    return(msg)

# %%
class Population:
    arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]*v.fit
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
     #create a new population with vizialization
    def create_population2(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]*v.fit
                i+=1
                clear_output()
                display(Markdown("".join([str(v.dna),"   ---   ",str(v.fit)])))
                #print(v.dna,"   ---   ",v.fit)           
                
    
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
                if i>200:
                    print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        return([dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]])
    
    #create a population from crossover             
    def cross_pop(self,pop_size,old_pop):
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        self.arr=[]
        i=0
        while i<pop_size:
            vx=self.cross_over_monte(old_pop,max_old)
            v=gene(vx[0])
            #checking if we get the target
            if v.fit==tlen:
                print("FOUND")
                print(v.dna,"   ---   ",v.fit)   
                return 1
            
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)
            
            v=gene(vx[1])
            if v.fit==tlen:
                print("FOUND")
                print(v.dna,"   ---   ",v.fit)   
                return 1
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)       
        return 0
    #mote carlo method of crossover rejection samaling

# %%
class Population1:
    arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]*v.fit
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
                if i>200:
                    print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max,pro_dict,index):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        pro_dict[index]=[dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]]
    
    #create a population from crossover             
    def cross_pop(self,pop_size,old_pop):
        nop=1
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        self.arr=[]
        i=0
        while i<pop_size:
            pro_dict=[[]]*nop
            jobs=[]
            for k in range(nop):
                p=mp(self.cross_over_monte(old_pop,max_old,pro_dict,k))
                jobs.append(p)
                p.start()
            for proc in jobs:
                proc.join()
            print(len(pro_dict))    
            for k in pro_dict:
                vx=k
                v=gene(vx[0])
                #checking if we get the target
                if v.fit==tlen:
                    print("FOUND")
                    print(v.dna,"   ---   ",v.fit)   
                    return 1

                if v.fit>=self.min_fit:
                    self.arr+=[v]
                    i+=1
                    print(v.dna,"   ---   ",v.fit)

                v=gene(vx[1])
                if v.fit==tlen:
                    print("FOUND")
                    print(v.dna,"   ---   ",v.fit)   
                    return 1
                if v.fit>=self.min_fit:
                    self.arr+=[v]
                    i+=1
                    print(v.dna,"   ---   ",v.fit)       
        return 0
    #mote carlo method of crossover rejection samaling

# %%
class Population1:
    arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]*v.fit
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
                if i>200:
                    print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        return([dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]])
    
    #create a population from crossover             
    def cross_popx(self,arr,pop_size,old_pop):
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        i=0
        while i<pop_size:
            vx=self.cross_over_monte(old_pop,max_old)
            v=gene(vx[0])
            if v.fit>=self.min_fit:
                arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)
            v=gene(vx[1])
            if v.fit>=self.min_fit:
                arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    def cross_pop(self,pop_size,old_pop):
        nop=4
        pro_dict=[[]]*nop
        jobs=[]
        for k in range(nop):
            p=mp(self.cross_popx(pro_dict[k],int(pop_size/nop),old_pop))
            jobs.append(p)
            p.start()
        for proc in jobs:
            proc.join()
            print(len(pro_dict))
        for k in range(nop):
            self.arr+=pro_dict[k]
        return 0    
    #mote carlo method of crossover rejection samaling

# %%
class Population1:
    arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]*v.fit
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
#                 if i>200:
#                     print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        return([dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]])
    
    #create a population from crossover             
    def cross_popx(self,pop_size,old_pop):
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        i=0
        while i<pop_size:
            vx=self.cross_over_monte(old_pop,max_old)
            v=gene(vx[0])
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                #print(v.dna,"   ---   ",v.fit)
            v=gene(vx[1])
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                #print(v.dna,"   ---   ",v.fit)
                
    def cross_pop(self,pop_size,old_pop,nop=4):
        jobs=[]
        for k in range(nop):
            p=mp(self.cross_popx(int(pop_size/nop),old_pop))
            jobs.append(p)
            p.start()
        for proc in jobs:
            proc.join()
        for i in range(0,len(self.arr)):
            #print(self.arr[i].dna)
            if self.arr[i]==target:
                return 1
            #print(self.arr[i].)
        #print(len(pro_dict))
        return 0    
    #mote carlo method of crossover rejection samaling

# %%
class Population:
    arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
#                 if i>200:
#                     print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        return([dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]])
    
    #create a population from crossover             
    def cross_pop(self,pop_size,old_pop):
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        self.arr=[]
        i=0
        while i<pop_size:
            vx=self.cross_over_monte(old_pop,max_old)
            v=gene(vx[0])
            #checking if we get the target
            if v.fit==tlen:
#                 print("FOUND")
#                 print(v.dna,"   ---   ",v.fit)   
                return 1
            
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
#                 print(v.dna,"   ---   ",v.fit)
            
            v=gene(vx[1])
            if v.fit==tlen:
#                 print("FOUND")
#                 print(v.dna,"   ---   ",v.fit)   
                return 1
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
#                 print(v.dna,"   ---   ",v.fit)       
        return 0
    #mote carlo method of crossover rejection samaling

# %%
class Population1:
    def __init__(self):
        self.arr=[]
    #minimum required fitness
    min_fit=min_fitness_val
    #max fitnss return
    def cross_connect(self):
        amt=int(len(self.arr)/2)
        i=0
        while i<amt:
            try:
                g=self.arr[i]
                sendc(g.dna)
                self.arr[i]=gene(recc())
                i+=1
            except:
                print("error in sockets")
            
    """def cross_connect1(self):
        print("phase1")
        data_to_send=self.arr[:int(len(self.arr)/2)]
        print("phase2")
        data_to_contain=self.arr[int(len(self.arr)/2):]
        print("phase3")
        sendc(data_to_send)
        print("phase4")
        data_to_add=recc()
        print("phase5")
        self.arr=data_to_add+data_to_contain
        print("phase6")
        
    def cross_connect(self):     
        no_of_parts=int((len(self.arr)/1000)/2)
        #data_to_send=[]
        #data_to_add=[]
        #data_to_contain=self.arr[int(no_of_parts*1000):]
        for i in range(0,no_of_parts):
            sendc(self.arr[i*1000:(i+1)*1000])
            self.arr=self.arr+recc()
        self.arr=self.arr[int(no_of_parts*1000):]"""    
    
    def max_fitness(self):
        maxx=0
        for i in self.arr:
            if i.fit>maxx:
                maxx=i.fit
        return maxx
    #create a new population
    def create_population(self,pop_size):
        self.arr=[]
        i=0
        while i<pop_size:
            v=gene()
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                print(v.dna,"   ---   ",v.fit)
                
    #crossover
    def cross_over(self,arr):
        
        size=len(arr)
        a,b=list(map(int, rand(2)*(size)))
        val=int(rand(1)*(tlen-1))
        return(arr[a].dna[:val]+arr[b].dna[val:])
        #crossover
    
    def get_gene(self,pop,old_max):
        size=len(pop.arr)
        min_fitness=int(rand(1)[0]*old_max)
        for i in range(1000):
            selected_gene=int(rand(1)[0]*size)
            #check if the dna quality matches the required mark or the max no of attempts have passed
            if pop.arr[selected_gene].fit>=min_fitness or i>200:
#                 if i>200:
#                     print("dna quality not found")
                return pop.arr[selected_gene].dna
            
    
    def cross_over_monte(self,old_pop,old_max):
        dna1=self.get_gene(old_pop,old_max)
        dna2=self.get_gene(old_pop,old_max)
        val=int(rand(1)*(tlen-1))
        return([dna1[:val]+dna2[val:],dna2[:val]+dna1[val:]])
    
    #create a population from crossover             
    def cross_popx(self,pop_size,old_pop):
        #print(pop_size)
        max_old=old_pop.max_fitness()+1
        #arr=old_pop.arr
        i=0
        while i<pop_size:
            vx=self.cross_over_monte(old_pop,max_old)
            v=gene(vx[0])
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                #print(v.dna,"   ---   ",v.fit)
            v=gene(vx[1])
            if v.fit>=self.min_fit:
                self.arr+=[v]
                i+=1
                #print(v.dna,"   ---   ",v.fit)
                
    def cross_pop(self,pop_size,old_pop,nop=4):
        jobs=[]
        for k in range(nop):
            p=mp(self.cross_popx(int(pop_size/nop),old_pop))
            jobs.append(p)
            p.start()
        for proc in jobs:
            proc.join()
        for i in range(0,len(self.arr)):
            #print(self.arr[i].dna,"  ---------- ",self.arr[i].fit)
            if self.arr[i].dna==target:
                print(self.arr[i].dna)
                return (1)
            #print(self.arr[i].)
        #print(len(pro_dict))
        return 0    
    #mote carlo method of crossover rejection samaling

# %%
psize=5000

# %%
def get_unique(p):
    ar=[]
    for i in p.arr:
        ar+=[i.dna]
    return(len(set(ar))/len(ar))

# %%
del(cop)
del(copn)

# %%
gc.collect()
# Out:
# 180

# %%
cop=Population1()
cop.create_population(psize)
# Out:
# TBBVZWZRBGJS QMPEYTEKW J QJHUU    ---    4
# EQOSAP OVM ZOYNUIUTCOGREDZHASJ    ---    4
# NHPFAWRBVZ H AHZSJRUDYIWVVJRKD    ---    4
# IFTLAZLCTB SCFIAOU W OXDAETUSE    ---    4
# MLYRMCCCRLTXMXYQ YTUVRBLLKTQVT    ---    4
# AFBNJ YIYNDBSOFIQLTDODXQNGWNYV    ---    4
# RWFSAABBDYBVPH DQUKOXCVMBGQARV    ---    4
#  LPWIEFFOIRIVITHINCEYR HC HTZF    ---    4
# DF   FWIPHBJXFIAO BESMSVYFRCFH    ---    5
# XGBHBEZIVYDXZYERXGTRMTFZXKMODR    ---    4
# XGXJWAZOLWPYHYGHDLBEQTACWENBOC    ---    4
# XGDYFZEPXRDX CKZORTBVWCMIWLJ E    ---    5
# NLTCAYNLKBP SVLEPXURUQDVAVGCMI    ---    4
#  HZPKFCWDFK PQLIK T OJRIGOBBSN    ---    4
# OOPHMWLMUEVYTSYCBSLDOF WDNZGFV    ---    4
# TLMSY ZV THPHPYMEDKLCNSYAVOCAA    ---    4
# BJLXUXVEMKIH EQCDDTEDYN IDRMLG    ---    4
# SVXXLGFZDXDPOLZWJSAVSE NPXHQZR    ---    4
# ATP ELJTHTTQLQ AKTTFHTLDXNUEHE    ---    5
#  M EUWIJKVHNPNPFUKPEVPOLAPIGXK    ---    4
# HKPEEKNOFEIQPCPDDMVOPKVIVFGHIV    ---    4
# HVRHMUASGQSXIKLZP JMSDETYLKIAR    ---    4
# AKRSEWCRJJCZZOEAKTQRBPGLOSISWE    ---    4
# VUSHQHBOSMXXFHOVSAKZDMQZVSBCSG    ---    5
# GFPATLCZDFBOZKPKUDZGJHTCAHXJUX    ---    4
# YYFHOXMBRMXXEGLHBRSVGNPMU SCVT    ---    4
# LHSNATCLVXVYJLPWWYHIDPHMDQTGUE    ---    4
# ASXHQBCATJPXHJZYRNICALMITUAEFI    ---    4
# WLKXI MRDPZD  VDCJDEMKTDAQXOMS    ---    6
# KVJEEW ADLWXFXOYUHEQSFKQXHJUBT    ---    4
# ZWQOXDNODLYJA IAUTFFQWXYNGFQPE    ---    4
# JWIUL KJNSXTWLJSEVTVLANWDHINCZ    ---    4
# ALYBFRJ WIJXMLHRTJNZDPHGHFVRFY    ---    4
# YBSUR DLDKJTUWYGDWBHAJFPAMF XY    ---    4
# RNPCY  CLGZPYHOMWLXHHTBIWHIDHC    ---    5
# OEHKACBAAQHKTXCDJ SEDXLDINTTRK    ---    4
# OLFLXY WFEQELCUEKWZYSGZUAYEVVP    ---    4
# IVBHFEQ XCJPSJSADMZSKWHXAIYKLK    ---    5
# XPCMSWTXME FYUATDURTKXRXQERC C    ---    5
# ADSIP YLIOWOTWOHSWGSZH GP SBLR    ---    4
# RFMJNRTUTX PJOOAMWZNKQBKABASSB    ---    4
# WDODIBAN EYSJGCKEAFPUE MMUIUPN    ---    4
# FUPAWQFDI OJKXLYE RHSSXWJXQARK    ---    4
# HARBKVZYIB J YKLQQWQVG SKJIQUY    ---    4
# KUPBM DOWWRNUF YFZLEB HIFIDOQS    ---    4
# WPLHY  BCEDXZEUGNWOZNYKUILJXUU    ---    4
# VAFXHYDOQCYLMPDJRETLM LMGJGC I    ---    5
# SLSATEMKDDFJUGUQTMDPST WVLFHWH    ---    5
# TLPHTVBRDTXYFQVSLABUVUFIB C DM    ---    4
# NIZSIWJJEJRCLLOSMY LZWIQXGJGGK    ---    4
# QQDHAIPQHVXEAIM XRVCWF TAD MOA    ---    4
# WLMUOTGVYU LVXCKH AHWTDNZFVNAR    ---    4
# KQSFZ CPOJIFU YBAZMTXT QOVMYRE    ---    4
# ZTUOEI APK UEROAVKMUDF GPALBLQ    ---    4
# KJTEAVOPTI JEFXIAUTIUTGYGONHHD    ---    4
# SLDKFSQLUHGGLNQKDLDTBTEHVWOY M    ---    4
# OHFF TCIDGWCSLCZOYFUQLBFEBIBUY    ---    4
# CMP NRUPVNWOZLLNSDYNKX FWGLDYP    ---    4
# IJPGAGZEPM X JQRTAINGQQCYMBPQY    ---    5
# BQKIP EJVCPTFLYCZIDJV  DK BCQC    ---    4
# AGHWPXZKKBMQPHHLMLEEOTWAAEXEBX    ---    4
# OYAHYEZDUIHZ T LVICWSIAGHGERZA    ---    4
# HJALAJCORLXKIUPXBQTHWVHEWDOYIM    ---    4
# CLHDMFUOOJ JQTRHWDTVQIRSBUIHAJ    ---    5
# AAZHAGJIYZDMPFV VAXJITTIXDZCSF    ---    5
# RYKHAWTWKDFXRXKQOYLEWQLPKOFWQD    ---    4
# YQHZINQIZAMGMLPBB KE WLDBRIERA    ---    4
# HLURSMOQUMGXHKN I LBTCNEOT F T    ---    4
# EETVBJTFSW QNLXAUGTWURJDFAIGMQ    ---    5
# Q G TNLOBLNOECIDQVTPDTOETHCP L    ---    4
# WJWGIPQ ZA JNROQXERGQTQZVLDN R    ---    4
# SJDFZVPUBEDAHCKNL TOSLKBHQHOJF    ---    4
# AAFLDADFOPKILRPADA TUIPVCNITUW    ---    4
# DBOUXQKVZIPKRHY Y QBSCNOQVIH K    ---    5
# BMVD CJTLDJZ L ODQOFVTOEW ZIEI    ---    4
# NLPPJGBHRGW YZWY MMADF QYJRCIT    ---    4
# BRPHVYFOWAVMFTGXVEELYXKJEVIIDQ    ---    4
# IRHYYSMDDXNXYIDRDKFISCRQACNMBZ    ---    5
# TPPHLFTEPWUXRWNKDRMOENWJCVSWGD    ---    4
# Q PMTIHHDJH CHOB STBIJBGMHTRHF    ---    4
# SZMOAKFNBEDRGEMFDQPRYGOMHOJ DB    ---    4
# CLTHESMBQLDYUA NSVTNSHLIAOVPKE    ---    5
# UAZCKPCSDWILOGOYFPCXVT LQCBNNW    ---    5
# SCQNXLZDT HMQLKQDXBORSVMUWGDOK    ---    4
# KBPFAPZBVWDYLLYA LOLUFWY BAYGW    ---    4
# TSQQN KXIYUGESUAUE NZTOGAVQWVO    ---    4
# VLSENZPORTDI EGWPXYDSHHUZPVQSM    ---    4
# LY HIOGYYRTH YOJVKGKQ VLC QZRK    ---    4
# DRQLJOCVSOAOIKIGDHLSXEROPFICWO    ---    4
# TTEPQ BOHK LFDZSRGX LKRSARSSFW    ---    4
# QWLA CCBZG XLHY PAOFBWUTABMRAX    ---    4
# YLSOZ LPPF UWROECMDTNAJUWP TMY    ---    4
# LLQBJ WHOBJMHQXQXTL JTXMQGADXU    ---    5
# ALUIA US WYZMKKDLFD QERFUAXTKF    ---    4
# AJWKA MOJALCXAKYBGYYGJWDHBCOJT    ---    4
# CLSHPRH RUKWTYNDNHZEPE TMXSLDU    ---    4
# OZMDPJCFTSJEY NARTZJXT USLRCJX    ---    5
# LPGPVUBPTLBAKDTRD QEUXQMVIQLK     ---    4
# ASHYSNCXHATMY AIDGALVW MDDGVVZ    ---    5
# AZHDLYC CJYXNNX DNQYKTDDRZGTCL    ---    5
# DQCPTWYOQMWMJLPAOYJHSTDMTXA OB    ---    6
# OQPKULMODFHUFMOLCBTBZXAEJPCNUD    ---    5
# QYKBIECDGWCXBFO OKBBRIEPUWBCJG    ---    4
# UOKCQMVCDESV TCGLKOEJKM HJOZCQ    ---    4
# GPVLJKCQLZJTXCOQESJXETTKLQKUBK    ---    4
# TJRUIZEUP SIIPOK  WTSCSCKZFWFK    ---    4
# AVLIACMRTUPHFTSPBFXLZAVMEZI TS    ---    4
# WZVM OHOCHKMCIFTUMCASALMQGJFIG    ---    4
# VXJMA OQDITKNLWF OWTKFODPHRMJY    ---    4
# VQXYJUALDEZ IRT W WDRJE EIWSGK    ---    4
# IKYR CZZHF VYM WGYI SNHGRGWTEK    ---    4
# AET PHCQB ZQWWDVQZWEIFITGQIBNX    ---    4
# AJPFLUUGAKGXFONLFMNKS FAKZZDVS    ---    4
# ILEQV KQPIHVU KRINOQRJJMCNYACK    ---    4
# XVLRBY AGX R BKCGJTYZWXOAPFLBG    ---    4
# ARXLQICEXB TAJLTZGYDGFOMUIHX      ---    5
# KIXXQVEODVEETGN IHIPSX LTLUZCX    ---    4
# HPJPUXGOUHCMELPLLSXXSAGMUSJPYU    ---    4
# RJDYX RXEHHT FTSDIZOCQCHDZIBUR    ---    4
# XQHSKGMX MZ EEESBMAEAP MPKDCBA    ---    4
# ASPFHMUUPXQDZCHGDBA VQCTABYCLB    ---    5
# ASHZCQYAD OXJDYVSHA SINPFCIQZW    ---    5
# AEPSUJHFKCCGMYGN PZESBBHACWRKW    ---    5
# XCPPOTOSOQGF DHAFXOYUJUQVWUFDK    ---    4
# YLLCLFKOHOFEVLEMZLQAJRFZPZIHVM    ---    4
# HQTHGWHLKN IHBZOM TWUXVMUSKLQG    ---    5
# SEGLGG EJQCXAMAKD PHTY RCOCRIU    ---    4
# UUBKJCRHJOVX NITJXQOQHGKAMPE R    ---    4
# AODXTWSFTVITDHFHEMLTPHCMALWB I    ---    4
# AUE YWFGLGHDXQKYEWBDQF UGU C S    ---    4
# WCANUPXWTFUQBLFAD  MD QBZDFYGW    ---    4
# VS VIBPJVEGTGZGBAWERJTUBAPIXJI    ---    4
# AJAENBXADULTIDOJJATWAOZKHWYIEI    ---    4
# ALOZXCMIEQKGAGGZXLINDTWAGOBGUK    ---    4
# CKZJZ CCUR OAMAEABXHFC IGONQ P    ---    5
# TKMLZTUKJOLGEHGAY WELOXKKLHE T    ---    4
# QJPAXHCGVQCENHSIXWEISZLRMFGCPV    ---    4
# MJ QWNCIEEQQQQQ DYQPRNWMBUSNBO    ---    4
# ULPPABIFOZPFWZEQIJVEZKC IDS DO    ---    4
# DFQFCNNLMZYACMPHR SENVDTTDIFTK    ---    4
# SGMUAUWOYEJAYMCXMZPZISJYKPISZG    ---    4
# ALTQLKYJJQ J PGKWIFLWEAW YE WX    ---    4
#  PWHPD VDMITCPOML OCJGYIQB ENE    ---    4
# CXRHAJREMNNVWNUAXENEQLGJQTBPLQ    ---    4
# YLPCYYGTDAIHWSIRMGBXNNMOYWXU I    ---    4
# AAJPPWYM NHXXIHNLVHEDBWFZLKCTO    ---    4
# NEYEKE E VSPZKFABYIHRQLMALIKON    ---    4
# LLSHREHRWEWFLEJTIR YZTZ FWMBKM    ---    4
# WXXD UZEBUQMJNWAC ILKWGYXGAM V    ---    4
# UAKXAQRXDUXXBG XESN  STAMRSO L    ---    4
# ASPHGCJK IOVVRAHVPHOPFBMZBHEW     ---    4
# ULUVUTMRCUDB ZLOJKRVOYHMVGIHFE    ---    5
# CSEHKTNOQNVQ BFUUUISUD YQIUVDO    ---    4
# PQFXKV JGHNGXIOXJFSNXWEMKGSCOK    ---    5
# AVUYAWOCAUHUDEMFKSLLNONMIRCS F    ---    4
# LHRHMBCUTQVJALMVFJX LHP XZS  Y    ---    4
# LSDAAOATQVWJKAYADJOECODCINMNCM    ---    4
# LLZHMSDNKWLZ NDZUMG ETVRYWDONZ    ---    4
# ERBHAPTFIHROBWDXOSCSGQXYZGYE W    ---    4
# AMXVJRSOELRYWUFRJ ANXOTJYRLL S    ---    4
# YKOBHHBVDFLMKWOPLPJZYUHASGZJ M    ---    4
# L OH  VJDLS KUXRGWOHVFQTKPUT A    ---    4
# ELJZQYPTBKUU MKVBACPQTCXVCSNJK    ---    4
# NLFLPTMYAFGLMLKSCGGABORMNXIKDR    ---    4
# JNKVK KOKQTP GQNDJO SFGNHQPSNC    ---    5
# HRHYMDVGYE KEHENA NPNI TEDXUIE    ---    4
# AVTPEFCXJL EGWBFV ICDIKZIUHUWJ    ---    4
# KDXHREXTGONNEBFRNWERJZKMAAHR N    ---    4
# BERHIYNJGECA YANPQTKSMVBIWCJLS    ---    5
# ALKPYBMKPKDXSFPACROZOJGSJHOCK     ---    5
# ACPAE SRUQTWAWCZHJDDTEQIORQMIK    ---    4
# AQAJADPUCEEZQUVPDFZATAHWZOOSJ     ---    4
# HLBZMEDBBPUYYLTEDCBMZRMNRRZE K    ---    5
# WSARAHTLDZALUBCS CHKA HMOJICKH    ---    5
# YTKZM TIRFUEZONJNNDESZPFOPIFUY    ---    4
# NNDPMXRILKZMPIOAVVXERTWLHPVWXQ    ---    4
# GDQAAWOHE ZEJOGLZTTFATCBRHIXPB    ---    4
# TWRHHQXSHP ZWRPAMDSFPBMLAPFFWI    ---    4
# ZHEORLNOOPCXFLFSCHABSAVNJCVZVQ    ---    4
# JYNBVR OKP FLBINXRTLYSSAKRINKS    ---    4
# MKQAOMROXAMZHUO RGAOTARXMGXHHK    ---    4
# AXLRWRWKQF XRXLHPWKTRNEGAOQHGE    ---    4
# BLODTBWXSQBFXTHDPLVENTPRJOOH K    ---    5
# VDHSAKCDCLCNZTCWHBBE  SIMIYN T    ---    4
# FQPOLUNHMENU ZEIIGFGFTDJRGDPXC    ---    5
# RLAHHVONIWHOUEVBX NBRDO AAMPLL    ---    4
# PLQMELFIGFSDUUEDDSCSKCGMWRGR V    ---    4
# TB WMEUUY LQSL JD ZD AQUHGUZTI    ---    4
# DRTXBMOZICE RLCKP SJCRJJKGIXXP    ---    4
# LNXHVSCCGJVGBHVEFCTZMG MIEMXCD    ---    5
# DZWAK ABGWKLOOLBBRTK F ATUIBGZ    ---    4
# FNOAKPBCDYWB SRDV LCRMKVULGCZN    ---    4
# T OAGNBR KGSLPFXMDHPSY IALICYL    ---    5
# RLZLADMAFISTKPZMYGTT HAIOVLHLK    ---    4
# AVBGYMJITGFPHHXDPVYAWTNMFX CXZ    ---    4
# CLFPM XSEAQLLLNEW MB JIOY ZIYW    ---    4
# HPPCSEUMPQ SVVSABNKF XSGASOKKJ    ---    4
# TJBAKPCXARBXFWSOULZLGYNMAHPWER    ---    4
# RUVHHWGQEAYOEUOQ JZTWHUOUAIP H    ---    4
# JLRTAQXLFISAMCVXVNXKWKLBAUISH     ---    4
# HYOKAROETEHYHTOAZDAKPNZZZLDETQ    ---    4
# AYJFAUDHDMDFHTVTGNYJHI PBIHGTS    ---    4
# UBPRHJUUTICY ZULZAL UJ MHSZFJA    ---    4
# Q VGFUMOXSMLTNEZDATNLYDSAPDVLS    ---    4
# YLLNDUUQXGYWG IVLPUEPGMENGZFRK    ---    4
# UAOOP BOAIQIPNSAAFCBSUXOFCPLMO    ---    4
# SKPG ZEODXCRPFEQXYJCMCGJAXTLFC    ---    4
# YEKVONEKK MGKQXJX CEGZ YNKI GW    ---    4
# WRP BMC UTACMIOVLNGFGIEGSTIACN    ---    4
# YLGWDHNOGERHEBNOZLATZFMMKBULUK    ---    5
# X XAOPIT HG ONIKRQBUSTVFANSCBJ    ---    4
# ANPVG IBDHODEVRFRWYDIZMGQPGXRG    ---    4
# BAYZDIQOIRZGQPEBW LTSGYNACKFQX    ---    4
# SIPSA FGXXXFOLFKRBEMDT ZIYLQCV    ---    6
# QGKSFBTOKJKMNLOXL VUYAWDKDMZOK    ---    5
# ILDPAFOWEQOVT UKBMFAYTYVGKHLCK    ---    4
# SXBOBFYJTEBWOZHXGNTFVDSWTGBO A    ---    4
#  GPNLVVSSETWQQGROITEPDMFFNRUUM    ---    4
# EYXAABTY ENZRXOY N VLMUHTF N R    ---    4
# QPTJAUTLDAEUFKRFJNTTUOKMHPEBHO    ---    4
# JVPIXYCTGIWZ VNS PCPWVJXLGVPLW    ---    4
#  KTHWFNVMRFCZVGAZSCESKOUVNEGPV    ---    4
# ANXFAHBPCDNCMFUASHSATMEMEHLWSU    ---    4
# ZZZPWAXXXVGHXLGAOWJEJFEDUZKQCK    ---    4
# HMIZAMZ DIVGIJLLCVXPBSBLC FC C    ---    4
# CJQH KBWDTEVVTCNKJAWLJSIGVICVZ    ---    4
# GHMJK CZBN CSLWEJHJBJFUANC HYG    ---    4
# UDDGTRVKCCJZQZNSW YECW ZPAYCBX    ---    4
# JOVYAWQPDPUCDLXXTAKSRDNJAZNXVL    ---    4
# WVEIYK RVBYDHNOUEPFBSRDMDHCCBV    ---    4
# UL F PXZHWDLTHORR TSV CFTSGFZP    ---    4
# YZMBARDHEZFYDXNADNTDYNADGQXAEP    ---    4
# V ZQX ESDPR GQIBDCEUYROFSEJCGC    ---    4
# AIAYFCOXQLOW QMFLPRNGITSJGICDC    ---    5
# YLITIHGDYFAKUQG OZJECZ LCTFBVK    ---    4
# XTCRCNILDKICIZFAMGTCCUUDHCBKCK    ---    4
# DNXMAY JBXHJRPZHMKHQCGCQUGIQ S    ---    4
# Y PCSPHONENGKRUSANSSJVJXHOHCZD    ---    4
# EBHGW URIECBYHSSSNWGATMDJBONHK    ---    4
# PWBHNIWBEJSU IVEJMNBRTRCLVGR E    ---    4
# AMEUYBCPVECPODMGV LDQIHAMZHZKU    ---    4
# FVYXB XUETQD KZNTZTXKQNNZGKBDG    ---    4
# DTIO TTARA JAAZOOSRSATT RGZMKK    ---    4
# RJOJ BVOGYPPDYOBFHDESEONRZCPZM    ---    4
# TRKDLYTPPL TVQIOD ONBHATAPI GK    ---    6
# PLPV FCJOWLPORN IA CCKEDRUIZMK    ---    5
# PWBUKRX ZEBHJHERUNZLZTNZPRSD K    ---    4
# UBSDFSIHIWBJ WIA STKELKSVKECAD    ---    4
# NRPWLIIOSH V ILCIXPCQAAGQBQXKP    ---    4
# XBPPH HUCGQBNDJVDN EFEUZMUBPAM    ---    4
# DCMSNNHFCHLCWXOREREEBGEMUTNYWK    ---    4
# ANDCRPEOJ RLMTCRUKXMNN WWBVCLZ    ---    4
# NEP AIMRDBWQTIIXN CJXGSFQPOFKB    ---    4
# Y NYVVCGJF XIDWDZCVLSUXZRFRBBF    ---    4
#  TVINHRCVECKOWOWIXTECGUESMTCRF    ---    5
# CHWHAEQMGSQP CRMTFBDAD TBAN IA    ---    4
# QMLDL LEABZMEODGUSTESWOOBDTCKR    ---    5
# CLHUALQPGEURDFYXNMTVNFWDYBWNSO    ---    4
# AIEXNYNOYNTQKB UJOXVSCUPZGTEWB    ---    4
# LLJHKVWAQXDAJIKQWASQWL IUWTMWK    ---    4
# KKEHKLZPOXWX YAML URORVVZPPUV     ---    4
# ALMS GRPAIHF SOZTEXJJPI DGIZ J    ---    7
# QQSZAEKDAIPX YSHYQKWATUWDXWFXJ    ---    4
# C QHYQPCNKUXHTIADKDZYRHWENMFFS    ---    4
# OOBHJDTHNT FQGCXJ FYHUUKT YCWC    ---    4
# OASMFOBRFH USLMFYMNEQB PEIQWBP    ---    4
# XEUMNLYAZR DLQGAYZTAMEJPATBOOS    ---    4
# MGUHAONOV KAVR GMTXFPKRZAQAGAV    ---    4
# FHMGPWJ MTKIPRORZP JTTFFACG IK    ---    4
# AYWZWPWVQZDRSGEFD HFZCMPRYIUUM    ---    4
# AFTAPTCOBAJYOXSFDDTPHJYV FGRZT    ---    5
# AYIIQKZOZBSU EUQEMUEIMWMTICAHC    ---    5
# SESHAQJDZHHW IOBZFMG VWIOLJDEM    ---    4
# FZPHT GNBWENWI MZATTTZCKEXDEUK    ---    5
# QCGTVQIDVMXYEYQYDQTKSQFMWAEEVF    ---    4
# DPUXN VCDIAPWQAHOIRUSXAMOIHYZF    ---    4
# BKSHLKAQ SZCKARBNHVJPTMMAXRCFU    ---    5
# OFPHMNWMAJOMFLRAMFOGFTUOMAURRQ    ---    5
# NSPHWLXQNVIORAQEMJUOSJILDFUZ I    ---    4
# SVPPWMCXDFFUOLXMWAQNZQKKIRZZVV    ---    4
# EWPHFYUWBADXDYDCD H WUSJXTTZUN    ---    5
# BNGBJPKOSEXWZUHHOWJEWNSUVN C K    ---    6
# CLPMELRUFPLTTVGNQTGBOMXMAUCLDF    ---    4
# ARNHSAW JXOIOKABOOGHYG JBITJKK    ---    4
# NSSHOQUPIDSXNHZV ZVEINHRL GB L    ---    4
# DWCHOLXWLSHCFLHZX MEEJQPVK UGN    ---    4
# UCEHRNZTQDXOILF E REPWXXZKAZCY    ---    4
# ANSDV ERNWYMWOXEADJERJEYANTROG    ---    4
# APD VNWQDEWAMWIQGKYJXTBGN LLUL    ---    4
# AKCGF WHTUIIOEGADDLMKPCAKZH UQ    ---    4
# AK FKDCPPGAIJBPATEXRZBQRUBIHWP    ---    4
# HR DG GRDEIMBRDPMUVKCFEIHVOCNY    ---    4
# GFPDPHTWD MC QFSCCPDWGVREMRN L    ---    4
# UKIZNSXVDESHDMHLTURZMGSCZGHJ S    ---    4
# YW NLWOXQEEYZKOKG LHRKZFARBSNT    ---    4
# PYPULDIYNVXGFPEV MAEAZ HYGNSON    ---    4
# VJWQINERDEDCGZPYZRNCHWVMUJVGPK    ---    4
# CIPJGZRBMQFTQFRCPJJLQHCVCGSQ K    ---    4
# YNAHBSCFTZRXV  NBQDFXXRYSLNDIK    ---    4
# UHANGMECXSB  S VDAISAJUHCUISYK    ---    4
# TUDKACEDGRDFFZUBTLTDGFDMHGRZZS    ---    4
# MYIGIFTLPEUCZHDA  HKIIGKMIWO M    ---    4
# ROXESZOVIHOYBLVKDATPEZCASCIKUL    ---    4
# JAWVIYX DYYKBJJGM BIETIFWJWS Y    ---    4
# TVFVRAPODEOOGLFLGSCBGMC ZEOGXW    ---    4
# RLFNSHMHNKXZNIOANTEGITFNYRUETS    ---    4
# GJZHZLZYUIJ FTX DFRLTQKMSGBXOU    ---    4
# QYMOBLYWUBWGYLWWDBBEGTBVRQYFTM    ---    4
# SLZZH CMSIGOBIKGOVTNMGKVWMSJDU    ---    4
# ALBSUWHAZEUFIEOAUUXGQZOMEEB ZW    ---    6
# OLUF OVVQT XBADGOZAISVVEIOLTKR    ---    4
# YEYDCBOVIE TEGKDDRLVSGOGGGKNRQ    ---    5
# GQHUTOCMIE YYRSVNDRGU  RXZAFMO    ---    4
# IIKRPJOGDHWC LVAOYVLWCAPYQHJIO    ---    4
# GOPHWDC MPCDVLPHYDLUVVLXTKKNNT    ---    4
# ZLDAQ YJRZRY YLBERDASYXEBMYEID    ---    4
# VZEAV TTSQGQJFEQBKVCMTPLEGZJ Z    ---    4
# JHPCTKTHDXLPDDIBDHAOXJKXWZKCGG    ---    4
# MLIHRJFKZJDXLZYXCBDZFM  YEFJXH    ---    4
# OUY TQC TAUPIIVCW YBSTFLSVXJRD    ---    4
# YDRXIQCOXWCYLOV ZUQOMANMNFQCCO    ---    4
# WRIHYXCCKZENSSRAD EH FULZYH VW    ---    5
# KHEMS RMDFLB UBUYIFLAP QQQLUKL    ---    4
# WLJNRYVZWORYXFFUAMTEBRR DYSDTK    ---    4
# XLYBKFTOAHGZZQHTP DQZEMSHFGCMF    ---    4
# NAGHUZTOFRPW YZVGBZIXPURGTTCIO    ---    4
# DSPNCNFJEFLYDTOMDEDPYFHMZVYTUB    ---    4
# GKAQO CANPGRAHKMUYMDCT GU LZWO    ---    4
# VVO XGQPJ TUNLOANSWYDKIMQYGOEH    ---    4
# OL KRECYQBNWGRPWDEN ASOYYTRKFK    ---    4
# QSVUESGIRKXTFNCGVXJKQT AAKGMCK    ---    4
# GQM J HYBO DH FDPTOEEETMTBJRZN    ---    4
# QLUZSUCGJUHLELOEZLKTOQPDGWPXIZ    ---    4
# LBZTARGOSVCQISJWR FVAUDFAKRNMZ    ---    4
# EGMFX ROKFJXEWXDOCWUXP WWFDKXD    ---    4
# BNAWQWVOGEEEV L DHIEIBRMZQSWDX    ---    5
# TBJWCZAPAYFQDRWA  UMMW MWQYSLO    ---    4
# OWPIDVOMMRDJQSJHB PGSI GUZQGBM    ---    4
# KNFHATENR  UOJ FEJTPKKCJDJ ILV    ---    4
# ZDNMELWMERPXIWOFCVQVSIWMRGEFWV    ---    5
# PWWPOTHYDQSZPPYODNBZMQMGAQOCFD    ---    4
# AYCJZAAAPTDR LILUBTTOZSSIHEXWU    ---    4
# TMPQXNSNDETTVFZAPYG YROCFL MLZ    ---    4
# WZLLMNBJZ FHVLISKXGKQT  APZSWY    ---    4
# TQXYKGEXBEUBGTHACBFQXFSWAWIJAO    ---    4
# YT RDCZOZLPM LZQFZQHSN VPUDYCS    ---    5
# DMBHIAZISBRQULYIC VSKSDLYXCM L    ---    4
# ELWSFXMPOXYANGONBYWCSFSYAAZATR    ---    4
# AVXJAWNUNS XSMQ SYREQLWZDJXZIC    ---    5
# XNVO UYGJEOEYQZTDTKQSKASAIKELW    ---    4
# MLHJKHYDIEZRZHQUD G LGNPA TUNY    ---    5
# WOYTANHEXJFN LDRUMNLSXEPKICOEC    ---    4
# OL ARIPLIUSCQCSODSNFSTSU HFTZG    ---    4
# RKQHWZCKZFRUTO ABWOCYTIZTXRDS     ---    4
# ULYWD QODWHHYPRUAYZZFEAV Y LKA    ---    4
# XWPYUUFEDKQREUDLDMSDSONLFXVMCP    ---    4
# VCRLDOCFQKCE CGN  LUHONRZCZT E    ---    4
# EPPHBEJGTLSGFVDDC AFIXAMTIUQTB    ---    4
# OJSHQABWTLUXTUQIIPTQSUCLJUAREO    ---    4
# BSETWWIUCGZVOROFPCWZNTBMABTPFH    ---    4
# DAVHBKLNRLENTZJIOBG WOAMTJBC H    ---    4
# EVXSDVONDSPA LVPDBWYODQPSKGPNB    ---    4
# GIVNNFSOXYIX WRBPOQKATECAOMYQI    ---    5
# MGXLOLVYP MHAFFAWCVFSUHMFDJCOG    ---    4
# FFCIK COHCMMMIUKMEHXSOGQLRDYPJ    ---    4
# HLIWTTCLGYLRVUJQSXYKHXLOLGP  G    ---    4
# ADTZITCXFTZ RUVFREWENFJVGQLBDK    ---    4
# OTQDKFVKQO ISOOHYVTFINSIAUSDEB    ---    4
# KZVYP YEQQXERLZUDVAGUTXKQQBTMA    ---    4
# ZRDSDBCPDFHIEHYEDMYFKQFS AIEGE    ---    4
# BBPUAOKHUKHVLFRXQ ENVLCXWYET U    ---    4
# MAPSAVFJI GWYWRALMVGDGMMKCRHJJ    ---    4
# TRNSSUDIDEOXXNCDLOOD YMALLJKTK    ---    4
# UZLSWKLY RPMTSKADMTEVUKRSAVLHS    ---    4
# YBPJAGEBEOIH FJSPZUNJCVMDLZ GM    ---    4
# YDEMAJ QSAUHPWBVV MICTFJACWQJM    ---    4
# RLUUVYSIDKXRTUOXFILHXNYPASNIFT    ---    4
# ZNAHASRGYASHWDYNNVVNSBPQGZWCRE    ---    4
# AKOHYEKRDUANMBPIILTERNDNYLGYLZ    ---    5
# AREKJGPLBMTK QDOVTKAMWZBAMIPLG    ---    4
# FRUPWQJWLUWWTJEXFDTNJD QAGFAOR    ---    4
# GBDTQ YBT  LQGOVAQHSOMKGWBIAZF    ---    4
# AP G PBIPYXJUMQRWSZEPN OIYNCDL    ---    4
# HEE BR MMZ X NIERULXCA  QAWVD     ---    4
# LXBSYKROAL PTLKAMKRAFBQLI BETZ    ---    4
# ODMHBBPOENHNNMRVMKZWLPUWOGKK D    ---    4
# JELVUCEZURIJ GEUDZQRQFYWYGSV O    ---    4
# ZIPHD MPRGKTKKTS GEYCA QUBPZHB    ---    4
# QTMWMZCOXFJPFYMGBITBNTCMHD AAB    ---    5
# BEISISUWDA  PEDISNVQLV ATGMALQ    ---    4
# AKGDA JALRGUUMXASVWKHAOROGWUAP    ---    5
# FKWFJKCLFPEHDGOMDTIHPWNQPMZ SK    ---    4
# QZPUTPTMOQTXQNWWC PTLA FVDLBQS    ---    4
# WTI ANROCJBN FHXCRNHGTLEWIKXPI    ---    4
# QJTP HCMAW UTEBARMINLCGLACGUBU    ---    4
# FLKYOULQTPTXMCTYW NXYZUQHCOB B    ---    4
# GTAJACQIVT TFL XVM NC L NHIYQI    ---    4
# GALQR NRDMGMZGAEX GSSQZMSWNDGH    ---    5
# PWKDVSCICSCWIUKNRQSMYXSMPIJCYK    ---    4
# QPPQYOJUCLLXA OJJBPRYAWTAFDMFU    ---    4
# ZJPRQIJYGDIDKVBKTLAELVHNOGRCEM    ---    4
# JLAYK TNCFVZBJXET JZEX XAZHVJO    ---    5
# CIEISGWOZXJTYLPWIEXEOXIKAWUQQ     ---    4
#  DUHBBJRGA DMPAMUZE BB  LHNCWL    ---    4
# NLRXTFCWDVQFSYTOPAYVEZJUNMXU X    ---    4
# QEPWPIKOHNJCIXRVNVTAXCRUQGPVCC    ---    4
# AGOOANRPDVTOWTNJHNGMKTUUYKEYS     ---    4
#  TMNAVCRBYDDDSGZIOTPDHPOICJ  H    ---    4
# RLXTISJNIW CACXMTWWSKAYUJGF       ---    4
# UQBYI YKVZJCDBOMDLAUHBB PFIXWQ    ---    4
# LELTHJYSWFDF W BDHMDOQIFABOSWK    ---    4
# NB HAZIOQNMGHKITIVOYDWIVRNLCHA    ---    4
# AWLR PKCC TSNNFOHGIERF GUKZQAK    ---    4
# RBIEANNBPO HEMHABSMUQTPJQSPZHC    ---    4
# AMEHWBYXDGSQOOHA EREKWANVOW MF    ---    5
# UULHNQ SDVBQENUWDWYEYKZFNAYRDW    ---    4
# SRLYSEAOGQ BWYPA UTGAX JDVBDQL    ---    5
# HMFWAFIJXEUVGATFMCLOLBTYDGSNFK    ---    4
# KJCFUJLMPEMVC ZZSHQYBTSSAGVXVV    ---    4
# DLKXTDEOOQDR DICY RPESZL LEJUH    ---    4
# BC LNXCNKECWQLMKCLTYDQQMFJWUNK    ---    6
# QNYUM MCYHKAGTBHISTRDTJAAJQCYT    ---    5
# ZVPPNFJTDSSRMWEZVRTHSRQAFYWORS    ---    4
# RLSMSOCBDZQVVHOI  M OORGUURNMQ    ---    5
# A PPIIATZ UHWHKVB HAK TFGGVDLE    ---    4
# AXLL FBPK UBZVTMXTTOEL MUNLAUQ    ---    4
# APVUSPHQDCHLAVMVDMUO QVR   VYK    ---    4
# ETSMTYCZMEBDELGRSSTEBQIZUTUKGY    ---    5
# AVFHHXIVZJTR PKAQULGWWOQYEIFIG    ---    5
#  LUHL EQXTTGQYFZJNWLRZ DIZVIEP    ---    4
# IB TKKCTYRWOXKLSX EAHNJMAEFIPK    ---    5
# ABRN JAAWGGMLWBZ MUWSMYNAMCR P    ---    4
# YEP GZV ODSXJPFDDIVEKBU JXZQTU    ---    4
# UJPO QLUIYIKUBZL EOJYTRMEYWP C    ---    4
# MLZWLLNWIGSXGPBZDJ XPIWTDABP B    ---    4
# VYSXRZMB YODVXRBDUR MZEDJGXC W    ---    4
# DPWVGBHIPE IYEGGKJ VTOOHCCICMT    ---    4
# MCCFVBXPGHDMWVVPXDFSCSJMALIG Y    ---    4
# LUPBVLIOCEFJOCIUKMGEQNOWXMHCNA    ---    5
# UZTAHMWQOCDXUGLENYHVRTYCIGNCZG    ---    4
# TGPIW CGWSPEJFXANGR  RDJCFYAJD    ---    4
# STKHHSOOD VSRKMXHNOOVUFNBHTCVP    ---    4
# JQHZLDKPOOXWQGOIHFTWSMLEICDZLK    ---    4
# LNZHPPHTFM PALPAAAHZBCKEGCKRFT    ---    4
# GHQEKHXCVQEMILMPKGHHAUTMANWF Y    ---    4
# KXGUEBNOVTDEFZNBUUKEFI WLDIBRI    ---    4
# YFOJAAQTOMVCL BMD NCS  YK L MQ    ---    5
# ABZQUTXHOY JRBZ DIEKHDYPLTZG U    ---    4
#  LIODGSOOYAIXVOJPMTHECIUWRGMMA    ---    4
# KTOBPJSONTNHVLZCGYGEKOGFSNIL W    ---    5
# YUCYRTXSYEKSS RFCQNESFPGSDYCAA    ---    4
# TDICAOHEBLAGGSOBB IUFKEQKGOSY     ---    4
# HFMIHAPOYEMQOIUABIYZKBRRAR KIG    ---    4
# IDZPMLNDYGAXXLCWDMPKVTRKQPVEJT    ---    4
# GCAUTDCUWIDH GBSXOGHZFUMBGGRJN    ---    4
# CJNWZACOLTNBFMEAAFBPUWTUFXECFR    ---    4
# ATHTAECLMEDNSHLXQMLIGDCVXBPTJA    ---    4
# EIPZS OBQKDJXROETHGEZYOVHDYIQC    ---    4
# LNHOCKTUPUBXJJTLE BEHIWVQDKLEK    ---    4
# AAPHKDXPDNHQHRWHADAWP KPWO GML    ---    4
# JAPGATCMJUEAQJFXYZXHFJEMSRA YJ    ---    4
# BTTYVSCAG  EWKPJMXHRKJRMSGQAHZ    ---    4
# TOISACEITEHVGUKHDNPGZQVLQFACML    ---    4
# ECHXFDCJMUNBFIKBDCPLSIASBAVP S    ---    4
# UOPEROOOIMYNYDEMFUFEKHJSAGZTNI    ---    5
# QJPWYMXKTNHXHGYKDK EXPN LMVDVB    ---    4
# AXGHOYXTQBTOHLO RFWHYNUHCQJZBU    ---    4
# ITMJDEPLFEDXPRHFDIZBISVLQGAHQP    ---    4
# RWAIBRROZEXTZDZFZVCZUTURAKXMRP    ---    4
# JQA UWSGGAMT EVAD WKYZVJINLFJJ    ---    4
# ALBMYYLZRIGCMMCIPU DKKFZAAITLP    ---    4
# EQWPPFWPDHZIXXPNNBTTPWMLFGISMW    ---    4
# WLPRAIYIADFPRG OMFRMSQFIJYSLFJ    ---    4
# RCEYNJEFL  XYHPJOATIJGRMHGIAGB    ---    6
# QVWSYIEXHSCKEBEAYJZLET WKGXYIM    ---    4
# BOPITMWDYEXNIQBXZSRCDISMVJPFPK    ---    4
# A PRDSLOMXWAVZUEVLOSEYLMJIHFPE    ---    4
# MWNHACAOXGRSPLUOHDDGKNODBSRQYH    ---    4
# WFTHNIODTUOVNLONSWEVMOCSNTIP I    ---    5
# AKNDVRLHLCFGFXQGC QOQXFMOXIAKT    ---    4
# KOTHWFPHSSETRPNPUBJDSF BHGIAJX    ---    5
# USZHGNUSKJZXPXOVN TBRDPWTJPWDD    ---    5
# IYPONZVKOGIKKYOINCUNSGXIRDKCTD    ---    4
# AVOVAOJXRZ NVTFUSNIIMTXMSBJCLG    ---    6
# KWWEQKYOWEYTMCJ GWFNESGWAMIIYA    ---    4
# WZPJAZUKWVILYFKUJLPOLTHVGGQJNM    ---    4
# HG XPWTOT XR BORHEWGDZNPMGZVRB    ---    4
# AKW BKERJTBGZQOVDBWFNQEPDLNCXM    ---    4
# NXPHPBPOGZBRRDMKRCJWFOLRVJQWQK    ---    4
# GBORARRETEGTCIBEHTTIMTYNAWZZZQ    ---    5
# ZMPHEHLDZRQPKNVEP U YNQMQ  LZW    ---    4
# AMKZAZGDHYMWHZRGYI NXTGEJVIJLF    ---    4
# VHYZTUAODC YLUMDDLVBKORE YV LS    ---    4
# KLUYZZNOGEKXRBR JICPKHUQILXLYF    ---    4
# AAPCSJRKALWKVTOWZFDKCBAQQDRCBQ    ---    4
# YJRCKIGOUHMXKXIYIRLEGQQOXKIPXI    ---    4
# OLWXG LDPXRARPMNQ GVYTN GFWJVP    ---    4
# ZLYZU UJKMHNQU MNETMSCBYOEZGUR    ---    4
# VBRRB  BOHFCEWGAMALDXNFYUDPCEK    ---    4
# TEJHFRUUHZRMIIUHI TDSXLB DVEXI    ---    4
# IJMKQBCXVH JRVLAFUIGJGXPTNHK T    ---    4
# CJITCMPPSY KUAO YQTFYVSPQXQKPK    ---    4
# QQMHNWBJYDRY ANDELPCGIKUOGPCJR    ---    4
# BSCDXUCCQEMGOAVRXHDEKVKQDGHQXT    ---    4
# ZTDHMMRDEUEN PEAJFQIKV CVRNBXY    ---    4
#  EROR CBDLXRRBPZZCBRKRPIECSG K    ---    5
# ZKCYAYARZEWIELORHELC PPGE ELHE    ---    4
# ALRMHYQNCUNRPWIUTPFVMTCESLIUDE    ---    4
# BHCBECVCYEYZJKABJNJIAIUMOZMP K    ---    4
# VPROAMSQZ XDMANXDYZOANKXAKIWRI    ---    4
# ALARLKJJDDQGXNVQEIQUYEXMKDLECP    ---    4
# ABHISOSFTSRXKWMIFLTEON NKFA QB    ---    5
# WSMYAOGRDLNK BRNVYDEBFUGOOKDXW    ---    4
# YAFGZLTSXCEXRCOAOIERS VCZIVNPW    ---    4
# JIHYAKORAWATUEOAIQETIMNDJQGCCG    ---    4
# FL Z IWX  WEAIXRPNKJNV IXGCCOM    ---    4
# MNPQTXQUIMZTUQNEDUTTRTITSVCQIE    ---    4
# JLIXJUWTBYLQ TNBDJAGHFKDAYBQAQ    ---    4
# HCSSA JDTNLCXL RIITISDLDYN MAZ    ---    5
# CAFPZHWHZDHY LOLDPZBQCZIMZHCLY    ---    5
# AIJMLZYKFEZAALGIOBGGSHITZAQXCX    ---    4
#  GYDUXISDHMVEVLAT TIXVMGUFYXGF    ---    4
# OEPFHOHJXHFX FITNJQCGW JPKYSEI    ---    4
# UWBPB PTKQ D WLFQOVVBRUNL YPYK    ---    4
# AVZFABWRGBMPPQDXRDESSQQFRPEW Z    ---    4
# NGPQYKMUHRASZZNAGHMPNJWT OUC R    ---    4
# YLZLWCURX TXIGYWJGPERNRUQTIKCO    ---    4
# MURKAXARVVPHLEBBJBTBBTCTRFZWZK    ---    4
# AGMPBEEOSSPTZLAEBBNPTPDMCQETZW    ---    4
# MR HV BRXECQQWZCOOSEPTIWJLIMYQ    ---    6
# IJIVAPJHDZ HJSGADGDVUNNBOHALMP    ---    5
# AUPADWJWN KIHAMAOMUA BDXEGZISP    ---    4
# HJICWBAKUSZXFN EE  MNT YPKEJFH    ---    4
# NYBHI JKDZ DNEAWHHFBKHMXOXXLQB    ---    4
# NAMANTNVYYGAMLBAW NWSWTGEOTFYI    ---    4
# IXVNPEMUDEOIWKHUDIOPNTDALJSRWS    ---    4
# ACMLGWPBCA XUCHNBJXRNNNOQIYCJJ    ---    4
# DIPXWDOJUPHGPWRVDITZPYOVAHLOZP    ---    4
# XUR K UHFBNHCLVXOXWXLTKZMIRG H    ---    4
# TMULMZCXGPPVRCHAK LAITEOPRWZAO    ---    4
# MCAHIUGKOFEK UMK ETVOX HSN CG     ---    5
# AQZXHNSLDXXG  NABQGCPUUNOJUAKG    ---    4
# C ZVUSCNRFHXATBDPQOBSICG GYVEI    ---    4
# NRGMRJFBOICZJWSVDKLNSZEMAMSICI    ---    4
# AGL UMCIQAMXCMLNJBHVD DUAHOIZP    ---    4
# DITPEPAWRK H  ZAD FIBW PAOUZMR    ---    7
# OLPPHTBLIVZHQXFSTYCNSPHUV IVET    ---    4
# RNANBVHKRWPXSFNPFJTYPEYMDVINVV    ---    4
# JMROGLD YE LCJ HDQLBRTOLTOMQSI    ---    4
# WFCHMYJONJZJUGHNDAWKYTBMZZOWFB    ---    5
# RDALKIG TXVSYSOKS TMAYONLSIOFK    ---    5
# BCNNLBCSKJHCDLCFS EARGPNAXGKCW    ---    4
# PLGGHL  LMZBJRQAENONOTLAJVG EK    ---    4
# MPLJCF CCEUNWHWV  ZBCLTJDR CIK    ---    4
# IAPHY JFYKUCIGDZXWQXUJA UTMCGC    ---    4
# OCFTPCWBDEVXPAEMCHAODBERAONMJD    ---    4
# WL GO OIUECRDELTDTJIU MMFNGYGA    ---    5
# DPPSIDOMSDTODSSZTTTEJTHFEMDVCK    ---    5
# QLP OUOHYYMUSACDA ECGBDMBUVGGC    ---    4
# CKMCGUUYDSFINLAHUPLPSTRYEPKQJJ    ---    4
# ISKXFOUJOMMXCT DOJNSFLESFKIC N    ---    4
# VPAAAZXQBWSL DODLCONEXFMTGDJOX    ---    5
# XYBBXEYJUWJTI GAFUT VHGMKXIWKD    ---    4
#  LCVBZHUZTKCWJEEP IXBON S IIDK    ---    4
# QZTMSSCVAH I LAACQLDGFPZWHTFFU    ---    5
# LLFCH JNUEGGQXOTUMTTIJGF YUEOY    ---    5
# VGBMAGPCVIKYNVM V TKBLZYCGWXYS    ---    4
# KTOG VWOGY GUZFWCDQLQTQMIIFDHZ    ---    4
# VBFZRRAOJOOZFQOQAGSPZTGPFVIZVV    ---    4
# SZHAEVYWCNI MFZMDBZEVJ DTMILG     ---    4
# AQJXIYNDEY U OYIGT AYIQLBNE  D    ---    4
# EEQKF TANEVKYLRHEZCEM YTAWNMWY    ---    5
# JAHSKGMOCBDGJLLBIZUBUVJZAAZZOK    ---    4
# RLACXHJSFRQLZYRPSBBTHW RPGINRV    ---    4
# HLPQTJBSGOGPIWHIN OJDKKMOIICNJ    ---    6
# AZCUS WYBGMN NAIZUKIEMZPADVTWY    ---    4
# UTGSV  OSIZXQ DNPK ATFFZA TIVB    ---    4
# YREFLVCQKUOXHEYFDKRELNJDDFEWFU    ---    4
# WLZEHGOAFXZDVVYFIUAHDT SAZFCGB    ---    5
# KJIHTVHJIBXKDOUANCMGMW WAXHONF    ---    4
# TADHAHZCQZBNHFSABYXFWJNKXGPFVJ    ---    4
# QRYHSX REEAQIZCNE ZIVZXMRLZTFB    ---    4
# AZW ZVMBDCTFOCRGFNTHFPBOZGXQH     ---    4
# ADFHSDOOFL LDBEBMXCZIRRWDFWQYT    ---    4
# TXKHVZENRD FZNKDNRGWPQ MYXZLFS    ---    4
# DLME XSTDFKJEGBPP ZLLECMUUGBOI    ---    4
# MDIHL UFKXTXBCDDJETUYRYQXAUGID    ---    4
# YBVHZDASATXS PZHURDNSSARJEQCXQ    ---    4
# TZQFF HCWMOBXUONQOTQUIDBZGLYUE    ---    4
# CLPHXGKBSEUVCYCVDENGF BEZQPJJI    ---    5
# ZPWMTZCREUYYBGHIKYOEHC OVGKDRD    ---    4
# VPTHPRSOLAKH JZBGSUVXJKHWCKI Z    ---    4
# TOXEYFOJVRMXLUQTIATNCLDIBGH  Z    ---    4
# GDZIAYCG AAXGQPFRANPPNEZUJACDE    ---    4
# RSGVR ZYMZONWSGAFQNKSW EVYSXHA    ---    4
# PLNAX CJKIPBCXLFUBDLWXSWVYPL X    ---    4
# DMGHIM IUIUJVLNPCXRYSMZCIMMI J    ---    4
# ZGPCDYRDXWDR KOA UMCEBWLPTWEBE    ---    4
# AVWCT XLPMD NURIWIKKSNECKQIZRQ    ---    4
#  ULHPPMSUEYPPSQSDNSU ULMGM EVS    ---    4
# VR W FCUFFEH LJLDXVOGMIKEPJBYZ    ---    4
# UKLOSQUUS  WSU ARWRE HAHEDIRCX    ---    4
# ARTYJFKMBNNN ZORADKEPMSAJIZPCC    ---    4
#  EPJKZOCHPCWACDHKJAEXAHTGVHC I    ---    4
# SZQZEJMMDTUEXVOLK V EWSCABZFLY    ---    4
# UMWTGMOGDVSVCEOYELIECQPYKGGRZW    ---    4
# BLIHMYUZIINZPSJBDSEOZSYRAIZHYL    ---    4
# ENWG DHOHPGBHLVXZ U HMWMTIHLGD    ---    4
# MYYSS KWDY YNPYAIUAPEHRQIHAOOT    ---    4
# JJE EROHJUVC QCGZDTQWYYMRPVCWU    ---    4
# JLKADZ ONEZZXEA Q ODAXEUBERAFI    ---    4
# SZWXCGFQFH XFFMPIK  VJWQKGECBQ    ---    4
# AHFCRLSPEXACRTZKDITUSSJML UZJD    ---    5
# VTLTYZLOWNAFSDVYY TETIFX BNXYA    ---    4
# YLBDVBMVIRAOOJPDECAETZ MZC OAH    ---    4
# I PEKWMKBANXWLIQ XTYWHPLNQLVTD    ---    4
# UBGIKVDEDIRXDTXA QUEQTTELRNPWG    ---    5
# FNNLMFYGEEQJMRYVPATDSE KQAERRZ    ---    4
# M WZM URDGR YHJTQNCMCCWTABWJ I    ---    4
# VZN KOKDBEXOWMD NBOASVOUAABOXK    ---    4
# RLBWFAIVYWSFISKMX YMIICKEDVS K    ---    4
# ZUAQZPTODBYNLPIDNQQSCTRRDJIQNV    ---    4
# VWMKX HNEOWUYQWVQQCEOB NQMRWKK    ---    4
# WARHAIGRZXMXZUXIFVILDEVPCOFCJT    ---    4
# ILTOKMAPTSCAGMJJDYD OTCBATJZHC    ---    4
# WSHTSCCNSSAGOLYBNEJGETMRIUEB R    ---    4
# HLPVCMSJPNMWFTFSASA CXPMPGLKDX    ---    4
#  LDOQQAEPEHXXA HUTMSED DWWOXQX    ---    4
# SA HCNRTCGBXIBOG CTEHBNIT QKYB    ---    5
# YD YQ NNETEMCZBZQWNDSMEYAGEUPY    ---    4
# ML HNCQTPRKXABEJJGQSDFRHAZLFJZ    ---    4
# POSHZZIYADPDQLVFVQSBSOHMDWMJNM    ---    4
# KPP HSAUCN QUKDMOLZFBFPTIXBM K    ---    4
# QETHJDOLPERAZPQAYPAFOFDEPGTTPA    ---    4
#  MEX HINLZGHPBSXNJTGET JXBK SK    ---    4
# GIAYNQCOBZ KEJOEIPIVJYQLITIKA     ---    5
# O R H FRXJVSRLIRDGDXDFJFOAACUF    ---    4
# XKXLKFVNHEUQICGIYGVSS OQJJICLB    ---    4
# IJPHGRXUFFNGYXOUNQITZT XPPURRH    ---    5
# ZBAHNHCXTJTOCPNANEPC NRGNG HQG    ---    4
# RLIEFNLWKKMKPIZADWDIRMFCMGAXDF    ---    4
# DDMPPTWT GAZUOGZD UJSNZMIXOSYZ    ---    4
# CKYHPICSDXPPYYFH  QJUJWAIZKWEO    ---    4
# RMIXAOUAQC URMKAXST PLGEFIRHTJ    ---    4
# PYTEDTUYOA KTXOSJUTHBJVTAPKFHX    ---    4
# UEF AUQGNETFVAHXAAAKSHZPXGKUZY    ---    4
# ORFJKOZVDEMR QQHDTNJMDFYDVGJ A    ---    5
# QXEHDPRRDYVATLFTR BNHFCRBDAENZ    ---    4
# XOB  OPLOS HILAHMNTCNHTZENIIZP    ---    4
#  BQTZYZUDEBXDYHAKIM KVQPZGZUWG    ---    5
# NYPHKE VAXSUTZSWEKOZVZEWAQLVLK    ---    4
# NKHSOWDQJEJXTIUSDOTSZGQFZXAKFQ    ---    4
# FXVCXJGL M J YCGDHSWYHZVGGVFVH    ---    4
# EGZVATOTEGYFUFNSOPVEQOG BTBC O    ---    4
# TVPMILTLCMOA XBLP KMOTDMFOHUTS    ---    5
# VZPEAC HEJKXIBQSQCRAVDNRAFI MC    ---    5
# WLDCGHEHLTZQJYRXXWDKSBUZAMUCBX    ---    4
# AQUPZEJBDBSVIIIQWGTVSTKILKMKTA    ---    5
# WOGSQMAJBDYXALHRT CWSXPNDRNRTT    ---    4
# ZSMQZRFAYRRAJLIJT NHCBVYFQOC W    ---    4
# ZLGFSGQGY WHKLFMDRTDIXUPPDNLIE    ---    4
# TRPHICCP ZUYF LUXAXHJIAMBRKSCL    ---    4
# DTOBWNLCFIVWWDSAOXEXLQNMEGKI M    ---    4
# GTUVQJPIWEPIPFPVGGUISK O DRUGK    ---    4
# GTB GHRODAMIPTEMNWXEUJOXXCNT D    ---    4
# CZCCZCDEDACFMSQDNO HVMKHKGBC F    ---    4
# UAVWF TUSDAEKKOC NIQSZGBLGW EN    ---    4
# CLLBZUMGMEZHELXUX XDEFNZLMJMZF    ---    4
# A HBQ MXZIDXDUZ NATDWGGUZNRDMV    ---    4
# BWOBO CSHVRRZHSHJYTCWPXMVPIKRK    ---    6
# VMLHRVPGFX TEPCDNHZEUSOMRWITFH    ---    5
# LZMZOMKCDWXQGQLKDTLNGT WJTVIKO    ---    4
# MCWWPUGJTEYPHRMAB  ULSBMUHARBN    ---    4
# HNPIJKTLMW V Y ZJPSEAAHLSOFGTI    ---    4
# AE TYHOADE VOBIROANVTPGVMGAPTK    ---    6
# JIUFU XDISZW LZPVOTQVWXTALGPWD    ---    5
#  KZJKK RD SZOLBKDSCUYTOOUXBKZW    ---    4
# OLQEM GTCKJUKJVS PREPNJAQUO SK    ---    4
# VLLWBBZBXHUXOISFDDDPDZVRCHRCNI    ---    4
# BTBZAAEDDVKPTCMSLFWFYTVMBXNAZK    ---    5
# BQND P MJEWMULMJE EQPL HN CLNB    ---    4
# QLHVMPAOWKBZELJEGXD JYYWKEIWHP    ---    4
# GVBGP CIBJITJNWGXNGEKQDMLRFAG     ---    4
# VKPMLRZQSG XONXSJXLBIVEGASRGVU    ---    4
# YXLH QBIAKABULOLFZ ERWOHMHFARB    ---    4
# HFPPVACXBPKXGLQS URUZEOCZKKBCB    ---    4
# RSQDLKZBAIPRXFFKLKWNVTCZIGICTA    ---    4
# GDPZLXMAWEKJDBBPU CNLRWHAHHPD     ---    4
# SEZDHJNGYELY MMAOARWJOPHWGMTUD    ---    4
# GBZFANRWIE GZ BYQBBEUHUFWOJVME    ---    4
# OIPPFDNDQFUX SJEIO DVDQGILKTFK    ---    4
# TJKHZCPPFHDJOHDXW VJQRIVMALC P    ---    4
#  IPNW EKPR ESAHLKMRZRITCTMIDEF    ---    4
#  JKYUFGSOEAXMBCSMRYUBBXMJIVQIK    ---    4
# JMSLRXOHNPBM F HDNY XP AAHR CY    ---    4
# NDUVSASAZGWTFYRZN TEP XYMUHDFK    ---    4
# SARRLTIOUYCJ ROLVQWYBYZKAUCMQL    ---    4
# A  NAALNIPGJKLISOXDISBYYAOZUEI    ---    5
# AJGPWPWFIYGXTRSAFNPLEH GYDMHBG    ---    4
# OLLTWRUGAQJPIKVYDAXHNT MEGNCOP    ---    7
# QIWGXACRDKUUBIACRBTEQTNBRYAMJR    ---    5
# TDVUNVKUCKEXMABLLVDESTFBHHEFWD    ---    4
# IXHPTFCVLUQYEDYAQDVZSO MTCZLRJ    ---    5
# DNEOPPC DP HJEYHQGTJDYNKBWEGEK    ---    5
# GVIUYRDBXBIGMEGAT JETTHAHAJQXI    ---    4
# LL ZRKIOXSQQOLYSEOTSNXIBXCG AC    ---    4
# GSMNVJUUJTVVKFMADELGSVYDNTMZ O    ---    4
# P RHZCRRWBMA BONM KOAJMERRDRTE    ---    4
#  AIVC CINPLVCNYDN CRVV QWNULFG    ---    4
# QN CB IUETVJKQPADTCELR CZRLEBA    ---    5
# FJFWATLGDRDMCEKMFKTFKKDUOGQGFQ    ---    4
# RKVQRPMYWMZQWLUAMSQX M CKHIZAN    ---    4
# MAPBENIJRETQEPFIQ GJHGWVYWB KK    ---    4
# JLPFRCPWVCHRLSOAJBKKLF XMWKQRS    ---    5
# CKZMUOTGTFHP LPYB MRCHMNAKHPAL    ---    4
# BO CA CRSNMSBJXVDYNHJSAEFEPBXA    ---    4
# VFMXZZCALOPGXCIVJLTRTT EPFBZHL    ---    4
# ESBPUPCOSE WYPOJCFJUQNFXYCKPPC    ---    5
# SVKXIWZOWXHBYHEFN TDSCILUBICDG    ---    6
# RUPV CCSDHKHUWKTX EHZGOPRRZ BA    ---    4
# PSEVI ESZW YPYP ASJEUF WYXQLON    ---    4
# FYFJACRSRW FHIYDBHEWSTTBXKUXRK    ---    5
# YTGL EL CMLMMLWT  TDMWGMDZKAMP    ---    4
# KLPBHVQOOERGFAXBYLVPWHWBFXJA G    ---    5
# LLPKS VYBHWYKYKDDOWKTMZNPPAIHD    ---    4
# D BGUOMUVKUX CGOFITYYHGIDEYIXK    ---    4
# SZEQP  ZGCWTLFCADVTUOUTAVNJ CB    ---    4
# X RQQUB DLUFFJENNLVCGPPMA AA S    ---    4
# ITSKANTOLJ PFPDCXATMWIX HRZSEU    ---    4
# DRTHPHCYXBWXBFCTJOYMPQQFAZTY Y    ---    5
# AVLDN HXELVRD IEQAEVSLGWSAMCCY    ---    4
# ZMBJAWXENKAUKSFJNTTTGU MYIKXLB    ---    4
# RKYWAUKROYUTLNFBCFXWUUPO GOB K    ---    4
# ZJUIBCCJELNJGLWZAGNFNY HICWCGY    ---    4
# AHCAPQYLBIFXXKAJENAVFHBMGWEO B    ---    4
# KJNBCSRVCEAPHBUGOVDEMVEMGOVQWK    ---    4
# MGDKYHNKYINZECALFGTMYDELAGPA Y    ---    4
# VZPHN HFR OINHODHWJVKBYXBMVYOC    ---    4
# HTQGP JCUDGGHKAFH VWSHIVWATP N    ---    4
# HXPKMQNMDAMHQIZHTMDESWFBCQJRTM    ---    4
# TLVYKOUJKPUTZPXWGVJPSQBXZWIV O    ---    4
# FF ADCCNBHLHYCOSDXEJRTJR AWXCS    ---    4
# ACWKBGCTPBROOLIAWFWLQRDZFRVTKO    ---    4
# YZSCAHUYMI PULSAJENYMGBKQWSWDO    ---    4
# ALNGCCUIMNAHXZSCAII KFLPADIENH    ---    4
#  NOOU UEZBSUZNZXIVUGSCE EGGE D    ---    4
# VGPGXGNTJKVQKBOZXYYOWTQIAZPVCH    ---    4
# GMGHESCUDLVNJEU JETFOFTLNAJOCL    ---    4
# TIZIDWXU EBXXFYKA FXGDWMZLBPYA    ---    4
# ZMHRZTXSL TDKCESZVXFYT NYWICZY    ---    4
# AXPISFOOPEAPJMOHBNXFFJ  MVKNMN    ---    6
# XPDXHNDWRUPSDLTAD XDLGMAH OAYG    ---    4
# KDDIASXXUEABTODTBCHHARANJNIA Y    ---    4
# PLNVHYEOSUXH TOZKFXTMKO PAUCGI    ---    5
# MLQHASNBJWHUZZWJAXLPRF LYNEVCN    ---    4
# AETNZ CYJBEW QCPFULCR XBYSEEPF    ---    4
# LG LSMC HS MDEBXQESBSDNRAVEI Z    ---    5
# AQTVZDPYWEYTRGOOTGQDMN GYFGUQM    ---    4
# PWXQAICRZMQNVLAJRKGLUX KCSPUGT    ---    4
# BOEAACBDDULKLKWSDCUWLM ZWOACYG    ---    5
# RQXGKHYTGDZRBBOPC ERIQUMYEVCWM    ---    4
# ZLBIHDCOK GZVCQHMYQIDCWMBFTS S    ---    5
# TTQYBKCMAEKLBLOEZENFEMLBELREAT    ---    4
# ZZCCPUCBNK SUSJED DEEARDNDHLZC    ---    5
#  LBBCXIOJQNXTCXZXHNSEXQWA XSBE    ---    4
# ASLH FETOKNOGNMBYZJPNPVMMEIFKG    ---    4
# ALFUAWRAPETIDZUCPLPSAGTLV HYXE    ---    4
# JCTPZBCONLXCEUQPDPSCDAD Y NADK    ---    4
#  EFQVCKODASABOMYDLTESLHQHUUOHL    ---    6
# REHMZOVL Z ZBIOBNRQZSTQFVZIHUL    ---    5
# KSNBA THXIP  AVNBLBCXG ZBQ ONX    ---    4
# QASAKQCBZUNEWIODJZSNH MMSCQCQH    ---    4
# CLFGQ IWZZKXMMXJIJRQOROEGATCOR    ---    4
# CYSHUKNDIKAR AOIWATFMMHIJB FFZ    ---    4
# MLPRLBCWNGXBHCDAXBXQN CLLHKMXL    ---    4
# NZKVDPCVOKLEMITMF JWYTFMIYXEVN    ---    4
# BQLAN RWDHSQLLVOGGJDMXBOAUAELH    ---    4
# THZFHUGOEVORD HTRJTDOEMMKMRXOK    ---    4
# EKMEL LM PBE ZICEDTZ DA SOMHOK    ---    4
# EETJVYCJNDO IOMADWTKYEHX LMLDP    ---    4
# KJSQBDYBBDIELLOCPOZHBTSMKUYQOB    ---    4
# SVUUWMIRWARAYVDOKFNEDJ TVTYC R    ---    4
# NLEQSKAHZEAUFEBYQPJPYA YAECGBU    ---    4
# NMXHU ITTIJPCVEYVMJMXW EHUVMUK    ---    4
# UGPTAOQATTHQ BOSLYWCQOTLVJCDQA    ---    4
# WLRMNGOYTFOVDJOODGCZVKAWAIBYYO    ---    4
# FSBZU WYCVV ULOXXPBLPSUEI ZX J    ---    4
# NYUMJQETTBWYILFWWIAEACAGAMBWCK    ---    4
# YLOWKOD WZRODZOXDZZ UHZOAJRJGY    ---    4
# HLRZDNYCVWPKQYMHDWBRVUAMUZRCZK    ---    5
# CCZQG IKPFJS WWTISTHEPSMDGOODH    ---    5
# IUBHIEYSKVGXUXVGC ULV UUAPGSAW    ---    4
# KLNRHDDSHOUXKLUADUFOECELWQOYM     ---    5
# ISX I CCS FOFY GZCJET  AVMBDOD    ---    4
# RXJENQCWFOGWYVDCS  MXTAOJOBCFL    ---    4
# PBPVMPOOKEXBK MSMBAVHTEGVFILCD    ---    5
# LDFXBTUOHJFVWNOSWFTEX ZMTNKGTE    ---    5
# AIPNZKILNBFEMIQOACIEHNNHLRFYTK    ---    4
#  MNIALEYXEVHHVGJXHAKBWQMUAPK L    ---    4
# UOWYJUOTOZ XMXJJDLPFKLIDASWSUT    ---    4
# TRQZCAFS XTS RLO BVDUBKMXGMCSU    ---    4
# WGQEI COQIX IUZAVFYTOYNUEYALQD    ---    4
#  KOWWNRWHTLQ WNEL ZLFMRIVZKCNK    ---    4
# LJZCAZCIIPPDXSOXEXFGN OCSZPLCK    ---    4
# AHNBHAYNLXDWRJNAZKIAEI HBGZEAH    ---    4
# FFYHPZNFQE QHHOYUOYUGOXNIOBSPK    ---    5
# NFEXATVITKOQVKAODFSELXGNXCZE K    ---    5
# DLCLNIE LZUTDIIBHCVWSIRMIVPOTK    ---    4
# JTRQMICJIFVSQYLHJ TDLK QN KPLT    ---    4
# AHHBCZYDKEUZYQODPLGODFBTUTOM Q    ---    4
#  QZJTONOXVKXSZLXMJJTLEREAAXURK    ---    4
# KLEOEDFOEXXYZMXJDZTETAVOBNCFGA    ---    5
# TJPRXHIJDCRIXKOJGQUB CBWNBICOI    ---    5
# ACPVP HUYSQPHMIQYCOWITFPRAZQAF    ---    4
# SZQNPOEYSDIMXSMA  TOG VPOBBREK    ---    4
# JH YBLQCWFWKCLVFN ABHBJKRMKC T    ---    4
# GYIQSPSODQWKRNODE ALULCKNVJVUC    ---    4
# JTTSRYSOAI AEKDAPLTLGOCVBOOCOX    ---    5
# COPVH B ZBTLYLKYF SRFKSBCJYCDW    ---    5
# GCMOAJCIACJPJTGEJ EGYGDYAYREIO    ---    4
# CLNXAYWNSVXRWMOXHPVWNCMTGJIXFM    ---    4
# VRPCAEPA NTOZRU MGRZSCEM TAKXD    ---    4
# FLDH SWFDJACUULKYMYJHIJHAUGCZQ    ---    5
# FRVMIAWOCC RCCOKISGEUQPLPQBJTH    ---    4
# WCGHZWDRYHIPPUILDJBNHDUMZX DRK    ---    4
# QEPFOYATEOBJEMVANMVRAO MJGIVYH    ---    6
# AJ HAUOFCHGJXCFUACXEIPYRCJWDNG    ---    4
# AGSGNSOABRUVLVCMDFFDSPG SBXE N    ---    4
# SUOWJQELDNAL QWNJODEFJPQDKIJRZ    ---    4
# RLOBAICETUMWYUHAKNLLMHBMNAPUOC    ---    5
# PTPYUFT WA XXB AQJBENU AVSQZVA    ---    6
# FCSHOCJRWTLVTRKTZ IEWKTRIGCD U    ---    5
# BPPHBGMKPOCHUPDJDGNSSJ VQAKMSS    ---    5
# AGOIHRCXOFNFXUEKB BZEOXJQXJCQI    ---    4
# DPVTWLQYDOWHFQHU HTCNJ ONGIYER    ---    5
# BWXLPICZUVSCLJUZLOPRCTEQUMICKG    ---    4
# MMJANJAF OCXMXYEDLCQ Z EJYHR C    ---    4
#  HLIAVCMOQLHVKYJV GEPGAEYJMHK     ---    4
# GXW NOCGTPJA CFPEBWD TZHOGXAIF    ---    4
# EVZHHFCIKJVZ KPNLEFSNLXUTUUCJV    ---    4
# ELBX AGHZV YTWGVGQXEWBBAUOIYRA    ---    4
# SPUKL KUBEEELUO DVBL TVOOXVYZG    ---    5
# MEP KABTZYFYCRUJNITPYVFSAPQI M    ---    4
# OOGSROKVLJQPFUTASKDEHTEBYGOIEV    ---    4
# YLPUCO EDJB TX YWHNJI QOMYKPKK    ---    4
# MBFKF MQZNZCQLEAHS  PAVWFGQMPD    ---    4
# OWJU KEPDCTXUMVBBRPETCUYJAYUNK    ---    4
# YWCVAMQOCCWXIDJQKFBVVNBMWFYDWQ    ---    4
# QFRARJCOPSXUYBO AXIDSHSQP RLOQ    ---    4
# BGWLFXBDODPXUOZGJLXUWCYMVLICJG    ---    4
# BQ YH HXRXFQSVOACIOEFXOBFXWILC    ---    4
# MFBMKUVDAACVJMUARXSTWRW ATICAU    ---    4
# I EFUYBIDTWW EFDC QSNSYZAEY PY    ---    4
# XGPLANVRETQEYJKKRQTJZCITAPXSCG    ---    4
# VOLSFCTRWPKM LETHNTXUOKMLHDU U    ---    5
# ULCLO VHHFWXCWOZDYMSOVJBBRRQYR    ---    5
# HTZFBDLGVNZIBEOSEUJH T FRHIB I    ---    5
# LVJQAUERTFGE BHJLATCP DYQGNABI    ---    4
# KPTTHTOTDZERNLVEGPLECROGLEZG Y    ---    4
# VAOIAFLNNUXOQDOYL RSDIGLRGQLIH    ---    4
# ECPWXMDUOE HOYTGDWGHTWATAEHVDE    ---    5
# RMCVZGLRSELGDQLNCDBEXGOFNGIJUJ    ---    4
# ALLQATKLEE KKJG JNHJMRIZMOIQSV    ---    6
# NBNGWIYFQJWFNCORFSWGTUXMAPLCON    ---    4
# AUOKVINOGQTNYPG ZRVJTPLQBEHC Y    ---    4
# ABOTHRTDNXZNHLDEGWOPLO PZGOJBQ    ---    4
# TPPQS EUUCCK QZFJRMUQCSSAJPXQZ    ---    4
# UWHQEJBHYAHRPICNZQTJI  MXGDZUY    ---    4
# XGXGO ICZNFIQLXMBKBJS   WURWAN    ---    4
# RKPZZDJLMOXONRGASKEZPF KAZERJA    ---    4
# AYSCR PBVNSXZDTYUMCEXWABYAZJZI    ---    4
# ZNLWETDCDYPXFELMDIPUSAFQHXLRJV    ---    4
# YLCGWIROW NUVUKYDWDF IVMYMUNBG    ---    4
# GADEWRFQPO XNMOVCYVRQAZMIUZFRD    ---    4
# NLMFHPFYFGKHHBOHDRMMTRHFFTUCNG    ---    4
# KGKQSQUXDPAUZ ERSQVLHT ZAYNTFR    ---    4
# MSTMTEQUDL C  HJZWLEUAXBBOUSMQ    ---    4
# AAPJQFHZR QGLLZBFM BKCGVG CU I    ---    4
# HLXISTPTZEBVQVFEY  PFMEQGUZUHK    ---    4
# XOPNYQREWVIFOELAPATPBPIRCR CJE    ---    4
# NNTYXFAFDMHTWWADNVBESQNHVXGO D    ---    4
# JXYKAM RXCVHRHOWDVCMFTWWYXY NV    ---    4
# PUUMAP GIX FEXCLDNKTNTDDU HNEZ    ---    4
# EFSEA KESRSIGPHQT CCYPEGJZMH W    ---    4
# QL FUACPNXPEDTOYEEKD CXTPTRCDC    ---    4
# SHFHRKM XCXLNNJIM AAQCCMNHGSAK    ---    4
# ITYCKXCBA RBZFZSGVLENZ PS KCDM    ---    4
# PTB UMCPCK XIAOL KYHJCZVLERLXN    ---    4
# EB QY GHQLMLNCJGD VRSSWLX JHOZ    ---    4
# XVQQPOCODWUSOVOMVFUVAFXI UCOCI    ---    4
# SLMBTIGMKNIEKGOGDSSJZFUMHPMNSJ    ---    4
# FROTAPVODTQKMHEIDTNGOIMHSRCQNX    ---    4
# GQOQYOCJMNBHYLOCHMP FBRMTYFBWD    ---    4
# EIWXUIKGXEMXNUQADWIKXJKMAEHHBH    ---    6
# FLPT XIWPIHJ ALETZXYIBVFDIFW H    ---    4
# ACMMEICEDIBDQ ECIRQPKUPKSFISYV    ---    4
# QLPRVRGMPRFWITHOXXNETH GYKTMOQ    ---    4
# TUUHE UTDYESMDEV XIHSKBJRFCE G    ---    5
# LLQMSSRKFENKPXONVWPIQJ PY OYCA    ---    4
# ZGQHCOHJ GKD JYDL YFXUQFASPADS    ---    4
# SPIK FB D VJCLDMLXMMVTZWGNIGYZ    ---    4
# OVMKRJFSQEJMKSOQDAKFDGFBYQFV M    ---    4
# ILFTCXOILNU DLLJE AECWCMCPRY P    ---    6
# BKVHZMCH ETKCNQROCKYGTESZQJYYJ    ---    4
# AEANBYCBQHYDPIORQNJWHNHMMPLSWE    ---    4
# PHL XQAYYEHFGAPPTAORWKCMNMIQCK    ---    4
# AOYDOFCEDEYRMANQFZAVAJDQ OYHVG    ---    4
# ACZQNNLQBHGXNWRVKKFBDXUJUGILCW    ---    4
# AIBGATTJAP EYSIRFVOYJDBPGDIOGZ    ---    4
# NJ HDUTSQDKXDNWSTLNZGTU TISCMJ    ---    4
# ZR ZDTOOWESMMLJQXVRYCRWRAFQXPT    ---    4
# EJXKPEFZVBVXBZTOWMQQST XHSWAZH    ---    4
# GHQZRFB LSNKLYWAY BZSMOAVOQX U    ---    4
# VFMYKWCMXXOD HESUFNDLI TVGYPON    ---    4
# FBF AKLZES NGNYHXKSUCR MWY CMQ    ---    5
# GDOZHJOTLKOATFVB  TEODUGXEQCRG    ---    4
# CQDHUNYOMDRSIAXUQ RTWS IZAQPCT    ---    4
# QUPMYNTOKV RCOUODULVREKO LVHLR    ---    4
# AYWICLH PL XNDS QUIEHPKFCPLKXC    ---    4
# MPOPQCRVXZ FQNNAOX  ZOMDREIY L    ---    4
# PLBSE NCABWAV Q F XMXYZDTGXQLS    ---    4
# ZPPJPZUJISFCLOVWK  RVC THSITFJ    ---    4
# TLOUGB HGGIJ LODMWFVSBAYWKHRZV    ---    5
# CLLZRLOBYL LHXFXYITE BEKQERYPY    ---    4
# EUNHBGLMP BVKHXADXXBMOAISBKY B    ---    4
# VWSJHDGOQY QCHTEJEHCBKIOKDIHAK    ---    4
# WVHITLBMYGHPHDPXXOTZSRVZFG CZB    ---    4
# IKNHZAOMMODXHPREGHHFJCTVFZICUH    ---    4
# ZZTLV CDPF XRUJNKNYTFTJQJNQCLK    ---    7
# ZALHNECNBTOWVXKMNOLRGTOBNZIQGH    ---    4
# SMPLABCVXGXAPRSEMWBR WOCXGCEJA    ---    4
# HLIKHLHVIUODUUKWEJUXSTOKNRXT      ---    4
# UDPRKIOFHZCOWPLNDZPVSCWLJGLDIQ    ---    4
# OCNWUQRFLG RSMKIN OTGYAJAMMCJE    ---    4
# RZCGMXEOJCGNEFYUDSNEIOWILBISNL    ---    4
#  LOTOHQUCAGYZDQTZSNVST NSDTJZP    ---    4
# SGONSYEBXBEXZLNBWHQKYZIOKDIKXK    ---    4
# ZRHZAJUO NUSNGOGRKUQSU UOUJSFR    ---    5
# REXVNONEFNYUBJVPVI EANKRANWN K    ---    4
# AKIOIWWBZFYG JOARGWXWOIDGFIPNC    ---    5
# RDTLJRSFDEQXHIUWLRXCFTFUTCWKVD    ---    4
# JPEHMNQXLEGIQPZNNPLEGJVXALBLZV    ---    4
# TVXRLTKSJOTVCLFJDD CFECFMUICAQ    ---    4
# GVP YXCQJETKDGBNPPQCP QMO NYFP    ---    4
# U PDHNM COYAIBLGY WVFX MNUDTQM    ---    4
# QLNCQGOQMQCWCLGAVGVKRNZXACGBXS    ---    4
# EWSOUEVKMEXKJTFVWATAMBYOEGGD L    ---    4
# PQPEAZCDJRNG QPKQXULIJTOAVJHRE    ---    5
# QQKI IHWPCJYEQDUDJHRUZ OHDQC U    ---    4
# FL ZKPKF NBZ KPXDETZALPLHHSBIY    ---    4
# IQPTAARFSCAPGIXBJVMLAXLMCVFCOZ    ---    4
# DNEQVFCZTGO MDDYSDWARX KAOISZL    ---    4
# TOOOAKKDVWZXAOO CCGFLTFZZUDX C    ---    5
# VLPBIEHCNZ WSDIGJ WCDWMFL HPGI    ---    4
# OPAJFACNVUOXNLEIQXEISZLNWLKZBZ    ---    4
# WLNVKDOXVY TXXOMLYCPQSOGJXMI D    ---    4
# QADBNDULGHHZJXOTN L WAOMARATYP    ---    4
# TYLWEHCXDOYTZPHXASAFSSCMIEIVXM    ---    5
# UTMRFJHD ADXMANKUVDEHTQXMJIZRI    ---    4
# YYTAF MKVTOV XHJLNZBSIUCRIYPNK    ---    4
# ADHOGFGHFGANAL UYRYVHSKIENJH K    ---    4
# DXFHPHXJYHYXOHONVYGEYZPFWGVCE     ---    6
# HTKTAJLXXGQTCAKIUQTUAR MQEANOI    ---    4
# IPXREECOTKGDGLALPQFECVPZMXKSGG    ---    4
# S LRWXVFMIPJYCXXD NEVRNJXRIVOY    ---    4
# ZGZT OEAENIT VCADLTMHECWCVTBIF    ---    4
# OPWGIQMOFNATALFKISURKSZMXBIGWV    ---    4
# Q WHEXSOLEQJKDSTJUKHETFMRFURDM    ---    5
# ZHWHDIBOSNSHDEFIYFGSWYUJAAOCZ     ---    4
# ASPIAUCUVTOMBGLQSGBWTMGODNEROE    ---    4
# ELNSAOYHYFEFWLYGSFSTXVIWAZVMEV    ---    4
# ARV XIY DP OBQOTOEBJEHBNGLAFUC    ---    4
# CLPKAM IIPYPOETGSEIKQIB MUJJ B    ---    4
# VEPWV KQPEPXIEKURRDGVCPHSLKSLP    ---    4
# FXMCAOCDDY WARWGJGPGFEEQ PBU Z    ---    5
# OH OLANEBOLTPPJOK RPSJ SIECC R    ---    5
# NCWHMMCJCKZELNSTQUWWZTZMS R CD    ---    4
# DWRLD DAJ HOXIXALHTRLQLMGJPVWD    ---    4
# XILHGASMADTO LIJXEGEDJTMBYQPKF    ---    5
# QJSUCRIRDBR  ZXKOEEYSFKSUGGHBZ    ---    4
# OVVMA DLXTOAE EKEVPEOFGVVGOTCW    ---    4
# OVZYHRHKDENJEKAKWWCECU YP ZJBR    ---    4
# MBSHCRBIPHMP CHRMLT MOASDGYRID    ---    4
# WGIHRIXXZLIAQLLYVIHZOJINAMNCZR    ---    4
# RPITFUEZNBRFTVPHDTTKID CVWIAWO    ---    4
# ILMXDGQLMT TCXJLUAMIDWBDACRCDJ    ---    4
# DAPIT CPLPYEVNFUVPCE CVDKEWZXC    ---    4
# RLNOTCIYRGNQFLNAWXUNBSNK  IDKK    ---    5
# YUYWU MOUACXBNZIEOFSNFSJUCLCU     ---    4
# ZZYSEZDUMMYXWLLQIUTSVKQLEJASXK    ---    4
# TSPHAOBHJKKAFONMEFLKNHXSOKCCFP    ---    4
# AVBYQLOOLDRHALVUVGQAUNIBKKQQ M    ---    4
# OXAHYECHJ RTWUXAZDYQTBQFITRM D    ---    4
# HLPFOSCWDG ASWDGRIHG NTPUV IBV    ---    5
# BLUPU  RDNYRXF RQYTG PQNTQIWDO    ---    5
# AGHFRRCDJTQIILETCOUECELXQIUSEK    ---    5
# AANBPNMLBMWS KYIEOOJWH CKJKCUZ    ---    4
# VIAECWS YJXISBBGFEWM KJMAGAKBK    ---    4
# YFCWAAYERU NTPOTNOJMSSHLQI VML    ---    4
# P KUONTNBGZXUSOOF  UOQCXBGNYXH    ---    4
# CL XDJV YNXNCVGCV KELO ABIQLHP    ---    4
# SBEEALMXJNBBJKFADFNAOMSMMXRNBE    ---    4
#  QRBIPFGSQIF RABASTKSCLBATRUVV    ---    4
# AZPQJCWEFCPQSLAPIB EWTEADBWJHS    ---    5
# AWMGVKXBIIEMIPMAG MZ P QYUSENL    ---    4
# DLICWUFBIL Y CHWYLB SDUPKPYTOU    ---    4
# J D QOFBUH JJUXDJZTEYTHVBDXJOC    ---    4
# ALYX GRLSMRDOKLP OGEDMLMUYQ MS    ---    4
# DO AKSDZRG AHLUJKQRFSBZHYIAG C    ---    4
# C AWNYIWYQ I VFQIJNERSHDTXITOX    ---    4
# BLGGFIBQDVZJILMAOWMSBJOSEWFAOJ    ---    4
# TOHSZBBLCKWJX PAWUGSSBSMAPS W     ---    4
# TODCZYPDCRRUFLPAQZKTDJGQVBIJKK    ---    4
# RLPRRYOD YDFFNMYWDFMTTZXL H NK    ---    4
# LKOKQAP CN QNCIYPFH SL HKTI XH    ---    4
# ILGWR CJJPFFNQREDNWQ ZZNTZGJXJ    ---    4
# SLUQCSOOLHFWQCDRDU CBXAPGLIHOL    ---    4
# R MHUVGIDEGOHAXCWUGQX TXBFUBAK    ---    4
# SNUOSYWNVG WMGLNDPBXCV MMPT GG    ---    4
# MVQESDIKHRVWBVXFDIT NI ONOTS D    ---    4
#  NGBKSOWD GQ OGYDEIQVHCKKPIAPJ    ---    4
# AYZEFTIOM  PTFPXD NKNPDGAAEWTZ    ---    6
# CLYID FGKDZKNINJZJZFSSYYEXFLOK    ---    4
# SSFPPUD USZDZRJBVJSERYNMRE C Q    ---    4
# TGGLEATCDZBDSABPDQDJSGLEYYOSTK    ---    4
# J PIL SWZYCZ BEWKGKEHQUQEXNADK    ---    5
# NXKMIJNOGZGH BKUEETVJHRZWPMU L    ---    4
# JUYIZRSSKAEMJRJODZTXSK  TRRKMI    ---    4
#  LERSVCJSIFXVEHKDOFYQWFSSPJKFS    ---    4
# PFBIUACO A LJWRLRSPEZNASB NQKL    ---    4
# YHRXKGOUFE XDNFLYOEIXPGPREIQEA    ---    4
# ATURGOFA EUXSUEGG GTJSKMIVTEST    ---    5
# AC AATIWIEMKLRA FMLLSLLQ CVJMI    ---    4
# KQP UNFXIHPPMLWQDMDBSNMXCZHKOP    ---    4
# ECSNFD CQDXMOKDLQYIESPJKAGQUNZ    ---    4
# AWYEISHMFYSH HTVG RIUTRUFAEKZJ    ---    4
# A SFIIPOYEJZAFKDBNDNOE CGDRMHQ    ---    4
# JOPOC UOGQALCGQUDBQOUGIIOIVDXC    ---    4
# FSLBAJPCGEEOKLTKESOPHF E XHRXH    ---    4
# AYVCNSQSMZTFYHBOANCPSVFNANIWDY    ---    4
# VXMHGZKOQLZZNZVNXWEB LMLTCQU K    ---    4
# JQROSCCNICRK TMUDNUOVCRBPG HVK    ---    5
# BWKVOQCAHP TGCAAMGZHFTGSABEOIM    ---    5
# LSTWSDEZNFCJQWAUHZPJSTCZWKXCFK    ---    4
# Z JWHV OVQENQNBEEKAIGNKZAHJCRK    ---    4
# DJHSASDVTPPZCSUAFPT IC ESWOYKP    ---    4
# LNFBAUAOYHPW RPBWXRGXDIMPDMVCT    ---    4
# VPWXORPAREBDZCUQNYXNFVHMAOAB A    ---    4
# DUFQAIBOQJMIGNZYH MXE  PMXSFNS    ---    4
# KHPQGSGYTGTAOMEAFGAEQFEMKQV MO    ---    4
# ABXZFPHYFM CTMOWDQRVBK DDIVCQR    ---    6
# TVPAULCSYLZH EBDRMVZWBHHBMIWJO    ---    4
# GGRQV EWHLYXOQCPDXZDRQYUKPI UV    ---    4
# IJLATHC FAC  PYWVBTXYH AGICA L    ---    5
# XZKXEVRSDEIP  RHVF QYTBFLN NGU    ---    4
# CUZKZTIVNWIWYBUDBXTPBB MFFOD N    ---    4
# FRRLACH ZXMSDLSAZWOWSWTJTJAFRK    ---    5
# PLKBAM OORWDHONAP BKKCIEVMYEXI    ---    5
# MJQUVICRDSVLT AKBR M M MVBHUTR    ---    4
# JQWHYDWWKL LCZOAZGRPGSFIYVERZE    ---    4
# CLPLRARVUEBCDADAYASWMIHWVVVLGV    ---    4
# RLVXGDBOF  K HOFGFDFOXLGUOTJRX    ---    5
# JLPQANKKZXTUVDASDICUSNOBTYFFTQ    ---    5
# OJ  C DWYI JRLMIBFWLQVBPAHXCEM    ---    5
# HEPNAQCO XGHUYIFOWVGBMHHSLEXKL    ---    4
# ELXTRHGPQWDFUWOHS IYVLXFUVUV J    ---    4
# JU QUGOYDS XNXOMPLHCGMLCTOGXCR    ---    4
# MBITYOHZMCHB GXUEAMCGV YMGCZ M    ---    4
# LNBWAIEPMTIAYRSJD YHKSQZDCIUAG    ---    4
# XVPJKXRMYNOALIYDDHTELFUEAKMGQK    ---    6
# AKK PHNZDLLLDHDFJ KGRNDKQRRMAK    ---    4
# AVTHEKDSMQCOHLJCSJLPBFCAAPIMXR    ---    5
# RVMXGXWROZKQQLBTJHSWOOSDN HC K    ---    4
# ASSMB OOYCAKOFD D VHVZJRSMFRZA    ---    5
# ADNSXRFKJUFUQBOADMMBVHEDIIUUFQ    ---    4
# QSPUZ RPDBYDNVBYDOTNTFSVQRUVPV    ---    5
# AQGGJBROLD DUNY F PURLSATDQB M    ---    5
# RWCFUYWMINQRJKGVJLTEVGRWKWBCZK    ---    4
# YSBHCOBCEQWCYHVPQQLFOSQUAJZY K    ---    4
# YPWDLOCUHAHCEDQDBMJ JV MWGXMBH    ---    4
# ODPTVOCGMOMWIDAOC MWZYKNJRKNYK    ---    4
# AXILAWYXHRQPAAXECNOEAWREABMNWZ    ---    4
# OXFWMVWWPM KMTCANJTUIV FBCHPPU    ---    4
# K VWYBCVOJRVZUOAJWJKYTGEAWS CJ    ---    5
# UGD G FIPMVRXVOYSVPSRQMMAPVBY     ---    4
# YRPUWBSVJOTUDLQHDHWOSEGJRPCXQH    ---    4
# Y MHSSAET IKIFZ VMLUSTDGHYWCIE    ---    4
# Z DXHIRIGCNNJIRVDGOYSKGNFGIKPH    ---    4
# ULBYZRSNYIRGAAYUEKZBSNFDAG ILT    ---    4
#  QPDAFOENCTFKDXSUYFELNYTSEIATI    ---    4
# LGHSDTWYDELAQOVPAXWEREKNGDYRKK    ---    4
# XZTPAUIGEEPPIVOBPHUARDJMXFHKXF    ---    4
# FRIHSKFSKASXEU  VQHUYTWTGUF TK    ---    4
# ONUWVVHEDTPAIHBJL OXGIDMBOLO Q    ---    4
# WPFEQDCMZPJTBJPTMIZQADMMVOIRTK    ---    4
# WOJEA FEJANXLRVSPYMHQGQMZDHYVP    ---    4
# CTGBURJXJNXGZJHBU XQVRTMUGQU G    ---    4
# VSYSDDCHGG KLNJADKVHRXJUGYF RG    ---    4
# ADWSTASMUKXETJXGZFAYXM E GJDUK    ---    4
# ARUBAQESZLIGPWZEVCD V NMXGVYHD    ---    4
# GVWXCGKOCS KDWCHOXRMSFIVYDI YZ    ---    4
# ZRPRM ZCSKPIE NVQ QEGCUWYM IPQ    ---    4
# YDKWFTCYIHFXIFPXXLTVATTWGADK K    ---    6
# KSHH  YGBADWRFSETQJDSPIBLUIBVM    ---    4
# LEIINZ WCIVX CUFRLDYATQMGYUDYK    ---    5
# MXSHUMRBVIPD BPXQ LNOKDF YIYUP    ---    4
# LSERS URMDMLHIADPATLOTROIAIQBL    ---    4
# FFBXBAOKLUPHKSIWY VMKJ HQGCKTK    ---    4
# JLPLYHKEQEKTILHUZXKDFUFMGYPADO    ---    5
# SZWEARHG OSPNLFIJLQGSYFVDTIHTQ    ---    4
# ELUWCYJNNC JBSU ASAASTFTTP WYP    ---    4
# YQYHTUGKAM MXBIAF HCRQHCDGREFC    ---    5
# UDPMLSOPDHQXJFGVSKXEDQCIJNNDME    ---    4
# SHHWT BDGEARIAOUJSFSXLJML XQGI    ---    4
# UKTBOVC OT RCLYKI YPHMKFCINUGB    ---    4
# JICIJ JGYICXFMVAMPRHADIMJGEAPW    ---    5
# ...
# VSCJBMCEYOIDAAHAJIXMMKY AGOBHC    ---    4
# OLGDLDJGTQGGVMQXSNIHU GOACKZ K    ---    4
# AEVRZDWGXQBYMBVHTLOEGGCTAUSCGM    ---    4
# BSSMTYJHXVNYALXAHKYLFTDPLRACMI    ---    4
# ADSHGFCZ DEKTCCCONZGDKDIEYUE R    ---    4
# RWELWVMQF WBSLNCLPLEINUFAVWBVK    ---    4
# KFPQPCZXIOFPMORRGICGIINGDGXW K    ---    4
# ANZKIMIOIEUQFWAOJNXJYW NM SQTH    ---    4
# LBNFAZPFHXIWHQOZZYUH ZQAFGJM      ---    4
# NPEB IUZ DNW IMAZONVSRHAVR WKK    ---    4
# HIPDBNP SFPZDMWSRWTSLDXRQAICRK    ---    5
# KHBUFKCPGLHCWPNYFLBEAKQMFGMARP    ---    4
# XBIYNEHCCLCOTDOADWCLSM GHQQORN    ---    5
# HGPFVGIYXDPICTRCDWGRNE HA KKTD    ---    4
# FLUXEBCYDDTXKQDKCZKO XLJUSYXKD    ---    4
# GSZWTTEOMOTO BLKDZZEUBCATQJBHK    ---    5
# ALIXCEETKNEKGAOBUEP MIHMJNFCI     ---    5
# BYFFXMUOEO TOLSGQGWQYPKJAOHXJP    ---    4
# XOBLNEVADEPN YNEPWRERKEVFKJQDR    ---    4
# OIPBNBPHFLBMLCHLQ VEKMJVIRTCGC    ---    4
# ACBMALCUQUDDWJPXAABYDOZDAK PMG    ---    4
# PJEISLQJY IBGIOFGYPVSXYMGPQCUP    ---    4
# PZCRKPKYISJV DNADLVYLW IYVWPUY    ---    4
# CKTRRI GZEVNYLEJN OOUHTMTOUYDT    ---    4
# FOBHAHOAAQCGU EADKWONAFURGXLGH    ---    5
# VYMHOFVGLIFLEUQHDQSCGSHMDQTR D    ---    4
# AOIJNNEDDDGEVRNGCJCBRFBRMDMQ K    ---    4
# EMFVYMCZYDF TLOTLH USDPWS CIXK    ---    5
# JWPAACGMDXWEKGTLYNXLSUTFX VUMJ    ---    4
# ALPESYOORB VQQLVBYRFNZVUVO LJJ    ---    5
# DQPC RKIFYFVRDQJDQZOWTCBOWMVTK    ---    4
# YIUAK RNRPYIRDELDGTFZSSCA MQHG    ---    4
# LZXYHCIIIFGQGLYADUERSHMMNNAMIV    ---    5
# IUMCAYLTLEVELCXFPNEYI  QJVRCFJ    ---    4
# CE HRDHUAHRRXZNCS UEFHMNNVEXGK    ---    4
# YDZXQICXXP XENSIW LRATHTXFXLFK    ---    6
#  AXNYKEPRENXA IZDQPMGFIGADZAJI    ---    4
# O GAIKPPAO XZQUBRZFZETYCCZBCBF    ---    4
#   RSPYJTDPHLNLQZKZTLAQNIAQPYBD    ---    4
# PSLHHTVOIQHAUCUYDYPLFAPPCCVCLS    ---    4
# PHWKQLGNAEWQIRHCKCZVSYSMBFIMQX    ---    4
# MKJQI QFXOOLQIOSDJ BX JGRYUZXK    ---    4
# AAXTWRMVFD NQOU TBTNSDZZKNACXB    ---    5
# ZYCDANPOXNXNYFRZV XYWBMBHCMF W    ---    4
# KDEHALCPYAAYURVAJXJTVJFMUKRPKL    ---    5
# JBPMTNVUREFJXORDWNLV BPMUQIDEP    ---    4
# DWXYAACZOGXLSKOMB XQBSJXIDICGE    ---    6
# GRMLLBMKTJYBKJRGHBTEV XMSZZCHE    ---    4
# HHPHAKCQMHLNJXRKW QLJPBVZWCIIZ    ---    5
# CXTHXSCXNX RGPJJF GEMNWMKVZBCW    ---    6
# QNHHLYHQCNZI BOVQQKFENQXUJNCYI    ---    4
# AFQUQCXOABDKNYZK  QTXZ QRNPXLW    ---    4
# YLSXAOFO HDULQNZGRTRDQEERKWCYJ    ---    5
# UOPMD HYSILSYLMKD XVTGLZCD KZL    ---    5
# UDOZJXKSMKUZNQLAPNKCQN MOEIBEZ    ---    4
# DFRDQKOCPN BUNOWMD EQHEBA GTWZ    ---    4
# ROK AULMKOCQ DZVDWCVOWCSPRILDQ    ---    4
# PWIAJECIAOVCHLIUAJMEAZQVTCAI Y    ---    4
# AKBOSVOX JWM XHGPRUESC FITNOHU    ---    5
# RTZUB FCLBPQCGGL VK VNXUMKIM K    ---    4
# XUL M NMSEUCJTAZIDJRZTRSAROVL     ---    4
# C GALRMUDOLBXLOSYESMRADDIXCTEK    ---    4
# WPYRRSIWMJKUELWZVZJERWUCBGIVBB    ---    4
# GONOWOCFLVIITLMFH EQJGTMPHBQIA    ---    4
# MOPQK GBDQZJVRNTIN TMDHMESYTEI    ---    4
# CFPITJOHDKJQXPWAHXAD FKSQDISYY    ---    4
# BQEGIICILXEBVCOBH OJPWCCK QHXK    ---    4
# VHJGIUEWRWNBQLSPNCTEXWMGHLRCEH    ---    4
# AMTUB MCDPQGMFYOAFSEZJIGCIGC U    ---    6
# VZSAKZAOVC XDLBUNVTIMQOWLOOECH    ---    5
# TXJGMYWGJA WOLPOM JESEQXLEAMIF    ---    5
# CCIUVIFNYGKYIOMTUZTESTVSJJMRGT    ---    4
# XLAXOGFJIXVVHMOOAWVERX LSXDJLS    ---    4
#  SFHPWBALOOIWROH HJEGJVTAIYDTF    ---    4
# ZLKFDNCFVOGQ ZWTIKTCMNDWEJISYL    ---    5
# PQUHO YBCH YHBMGDJ Y FKGCE GZX    ---    4
# UBNALRQYYLUXTJY DOFEXMVM GGEPB    ---    5
# TYCSBCNMTV U VOGDIEUHPBZYAOHHZ    ---    4
# MLMNKVNIGZUXMNYGACFYXTSMMJDPQY    ---    4
# RCVFAHBWDNSXB DD GTAFNMZJBJBNF    ---    4
# UEQHBNJ HELYTLBFHRGMZDAFTGHKFY    ---    4
# HLUKXKRQLB PZFE UHNEMHCMOHMFEV    ---    4
# HZYOVQCFXD WPAEWQBUIJTOYDGNORX    ---    4
# JJKPAZCBDIRZTQWWHOOOJSRMVPOZTK    ---    5
# UMPHA JEOHZBBEUNHPSPXFJWYQMSRO    ---    4
# WOAJUKKMBMMX FMATUSFTYZUHRMCRS    ---    4
# ANSWUHCDJHSGOWLADUBKALLEKDKGVL    ---    4
# I UQJ KPZDKFOFONVMULKLNTW ZC G    ---    4
#  GW DKQOSG TTLULKGPMDNWP KV  P    ---    4
# DKPOOVCFSTKCFLTCXOXQSFGGSNLFHM    ---    4
# ULN QOPSTUOUZWB DGHEVRBNPLDZKK    ---    4
# WLPRQQQEUNSWNC ETVOXIWJMBYVH U    ---    4
# UDAUAACGAGKCQUGAWETDISTYORBQNU    ---    4
# XZLHI  JQKKNS BGDSXSISKMMFKLNH    ---    4
# HWVAZ YOAGCFXLCOHGLLOYGCHGTYFD    ---    4
# YLNLZNFBUXWGPLONAPXVEKQDRGKIRW    ---    4
# QJGSAPCJBVQRWBOFDDJTSODZTWHFCD    ---    5
# IIPTYROEG ZHGDODIBMXBTKNUVIJFR    ---    4
# EP CZPLWDEBNHOOXXIMFBGGXIBNJ P    ---    4
# ADYBW SMEUHMIDZPFYSPHF TAVTDVG    ---    4
# UYCXZ RIXVMXLLSAKOWYR WIANTSLY    ---    5
# KOCBZRHMNLNQRVOPQ T BBCMBRO YE    ---    4
#  HVUVBSNGTSX KHYFOQRKEWAAEFDEK    ---    4
# RSVAKBLNDEMKBQQRWRFFOTPHS IEFU    ---    4
# KXJX OSZHRFVFLVFZ EVSAKN OIGOL    ---    4
# DQNO JVOBZJY CPLFRWVUVMMSGNZOU    ---    4
# JENUR XFSEMXMZYPUATELFTPHBBXOH    ---    5
# KGPOG HGPC VPIRZYIXDMMHMGCE QY    ---    4
# TTBKJDV DVOXJTOSIYXMDSIELBLR O    ---    4
# YTRBG BTUSVGDGCRBZLITVFMKGXI F    ---    4
# YQVZDRHYCE  DHTZDQTXEAFXEGX PV    ---    5
# AHIJ MDOPJ PDJUPAMFEGXRTLJKDGT    ---    4
# YXRHYJCCNOVRIXQTXQTVOJWMIAJCCY    ---    5
# RARXJYNVJYOZPWJYDQBEXCMACPICLU    ---    4
# TLFMHTLHHVAXRJOP WWGIYICDJQOBK    ---    4
# CKIWXONKZNTX VVVNSJEECQTMIPUTK    ---    4
# PYPRXKAELEEAHRQYHOD WYKUAHLIHK    ---    4
# UTFHBFNFAOWXWMH DWEFWY DDYCNIP    ---    4
# AUKRXMCXIMAZGAK DCMCCYVPECCJ N    ---    4
# BVYFASYVD ZNKMLZGHCUSEDPXVOE I    ---    4
# FEFHNXCQRMPXCXYJWGRUHM BDGDCQW    ---    6
# OLHOEGCOYHEDXDYHDKWFCDWAYP HHQ    ---    4
# RLAXSNEHNCBHCZVQACOTSLXFAVQJVK    ---    4
# MCUHX PEDMUFITBAGTMMRANGXJLQKE    ---    4
# RLTBIQBOREYYEGKDC PIWJDKIXIWXA    ---    5
# JLSATP RGQRQELPAZ  Q THGRFSJIN    ---    5
# CKOQ DQOLETUCUOONHGYDGBQADSLRM    ---    4
# OXDFMYCCIHTUDLYKZSGEDJPL VKBKK    ---    4
# TLFHTBPNDRQWQEUJMQEEAFGNHXPXMM    ---    4
# GCKFQJQPQVQK NANDVTHDCVQAUFOIU    ---    4
# ITGSIIGOVGCYPLPDANIOYYHBAGLYBU    ---    4
# MRSXHFRHGDIQWIFVG KTSQCNALYVPK    ---    4
# LTRTK CY DVIHDORC IUYOMJWSJSNA    ---    4
# DEFUQLXGGMRXZXKAFMTS WPQCGXDYB    ---    4
# KSPPBUDUMNOB JDOOD EVTXFMAIZES    ---    5
# MWNWANYLXSSCZQPADHELKO PSSYVKV    ---    4
# NZPHRYGNRWZVPPXFQBCZSKGVNSYCEQ    ---    4
# YTBKALZWI MAJGOADZUNABMUAYNEWK    ---    6
# AVUYACICDSENCWRJXKWUSJKAEBXGTN    ---    4
# OE KUJTOUR MMVQVDXXFNSSSTJCF P    ---    4
# QYTNT FCDBPAXPRADLCGAPIAWFQMTA    ---    4
# JGYPVIZVRW GHGZBZZNPUTVMA CWMO    ---    4
# QJJJUWQOKEERHOUAKUTYEFYWTZIFSJ    ---    5
# RLZHSSCHIBNMUBYSVSWEITSKRIJISQ    ---    5
#  L W  ZOZKGXUXFUZZGNXOLXTZKFDH    ---    4
# MFPZGAIEWB RFLOVJMPV VXO EYVZF    ---    4
# H LUR ZZSNRXVJBMXOTVFI  ZEHNFA    ---    4
# SAAHRXD TCFOMCNHG MHUH UGBISGC    ---    4
#  JMYWIJZJECTCZOADRTTZEQVQTPOOL    ---    5
# FNQZRWCWEI YEOPYG WGHCYHJDSZJK    ---    4
# XWRZGUQACGLK RWXLGEHZOOJKGECDK    ---    4
# ILTSBFCJBA XNFNDTPATPSMCNBOYOV    ---    4
# ABTQHJJZMCRMHBIFPV KDL FDGLCKK    ---    5
# KNHEAUYLDSBRUHOSTISGIDYIIFOO V    ---    4
# HLPFEIZFSSWCXGDFEOEEQMBGGMIQWP    ---    4
# AOP IUKPIACUCPFSUFTRSMDIXFEGK     ---    4
# ARPWAEAXAETZHGTYGTS KZRQ TRBEB    ---    4
# ELPLDDQBVGBYK AGNVIKSKZKAMISAL    ---    5
# VKPOERNEHZNNIMP B AXFHNLAXIM H    ---    5
# FNYHYVYXTINAGHXAF VGTHTJRGQSGA    ---    4
# OTXXU QORL XJYZBQWYFC CLKHVCAA    ---    5
# YYPDPSC TS QKDLYUZUJZLSMAODUMP    ---    5
# HJWHAMCWNHZHMURHFINGJMEY EPHNK    ---    4
# AWFNZ XOZWYAE DZYEAZQJBIXGUOJE    ---    4
# OCJYP JRJJRXCDFHEEJABMOBAPNCBD    ---    4
# RYJVIEVOBBQX WBTYAWHDTDJ KRRPE    ---    4
# DJHCFMLAUESXXZQDBWT KLWBG ST F    ---    4
# BLUNEBXSZGDJEWFKCGCNDU SCEZJ K    ---    4
# PKTE YFHRAKGVLMAFPZAKP  WSBCDY    ---    4
# OHPMGHS GB FPYOTDOKGLQBHXSRPUJ    ---    4
# MYMXKEUKSYUXALOTSDUHLTQOJ A JB    ---    4
# GPWWKDOOEEBXS XAWHKFHMVONIEHYC    ---    4
# NEJQKKCGJJWPIZSAAUVEBSOATGLWEP    ---    4
# NJJFAYCEKJFKEPWBRONHSLAXTPICAP    ---    5
# ANTPRZPUIWHLYLXFNGTWZPELBYS IK    ---    4
# M OERJCOAQ MXVQXBRDVNTKK KXBNC    ---    4
# XXXBBQCDJKBKQRQAHJLELBAEAFXURO    ---    4
# ABXFCDGODEGEXUARLNVFZWFFL OTTR    ---    4
# QLRSVN FRFLIMYKVH SEXZFWWC KPK    ---    4
# MLBJTMUOVY YPLAXIBWMCQHPAVXPHW    ---    5
# AYZRONCNSIGDRL TBAO HXHSEPIQZT    ---    4
# QLIXULQBSU YATKOO TVDTNCOTRAWY    ---    5
# ANWTU ZYIEYVSMOUXIKPCMCMHFQLKQ    ---    5
# PLTHYKURENUUBVO ZDXOECZRJGX IP    ---    4
# ABZHFRXQCC GBRYJT GWMXBRAVQPJH    ---    5
# HNPXSOTWHZOXBHIKPJTYUSIV EIKRW    ---    4
# JZITEMUJDF NHS ZV UMCZDPORBCXI    ---    4
# AUPHYJTETJPRXHWXSLRBISXKQGXOI     ---    4
# ATCSZVCJJU LWFQYV UKWYMK BXJKN    ---    4
# DJAHY FYUCIPSKIMREMTTCHBAGIHZU    ---    5
# NYSKT OOMERENDOVQWJLMJITSKKIDC    ---    4
# J RWECV WTGZHLCKBGAEERW AXUQ G    ---    4
# JJYZD CYWSZCIUYAOIPKITZBTLVEKF    ---    4
#  HSFFDIJBENMCXZPO GTLUSKOHPCZK    ---    4
# AWWXAXROKLAEXTKFDNN XVLZDCYWWL    ---    4
# BMZAAZROIDTEJTVKK MALATPAPMCDJ    ---    5
# EBPVZ OYQTJOKXXCBYLJGBNEAGTKII    ---    4
# DPUTYWMSDRRIITIYMFKQSSAGDGINHQ    ---    4
# JYLYXWVKZJZAON NVHT FN MJKQCPC    ---    4
# MCGHAWXKKHUPUYJWDDCHBTJOKMBUSZ    ---    4
# RJPWQVAQLR ZQJOZZFGWZA JURUDQN    ---    4
#  AWDAYCUDJATXFOBWCUE JHTRDAKO     ---    5
# SUFRYECJR BMJYOUSMVENUZRZZGS O    ---    4
# SXFPS WOHYUQYMGAGONFKF DWPB JB    ---    4
# TWPEDXASMBSDGLTAZGCTRHYHNYNCBE    ---    4
# UY AOCRPME Y FJZZVCINVEKADRXDP    ---    4
# VXGAIDXE IVYRQODNBUERTSDLVVTYK    ---    4
# CEMPB VRBTCXKX IXMTHIDIQAXRHEE    ---    4
# GUSMAYCUMSPIMLIYSGEJAPGMNVFPNF    ---    4
# ZCPICJEWAZRB JUID FBBO KGJDXDZ    ---    5
# NISGLMTRGELDNUICJ PKBVTFADIPQQ    ---    4
# NVAQLVVTNYKSAKMAB IWMX WJXGLDK    ---    4
#  HUPS TO ITHTOVAJWHPXHNMPQK AZ    ---    4
# AMI KOVM DKDFRBJVFZDAMPQAWGC M    ---    4
# PGNQHIFWWDCR ZOWPCSHPMCPAQCZ L    ---    4
# ZHKYALUONN EWZYFWLQIXE WIIRIBO    ---    4
# HFJZYUCZENINILGJDVUPEBNLJDZCRG    ---    4
# JXWCGNSGCQVWTLOTJHTPHVMDAFHHDG    ---    4
# ALMYEIEOBDGTYPPIKUZWSWUXDGUVZX    ---    5
# IENHPDCRLEXWMUVDALMPWTEI HAOE     ---    4
# HLBCBHZAUCUHALQJLKTZC SJGVDJAK    ---    4
# NLPQVEDOZCALLBAHLTQUSVISGO QEC    ---    4
# JQPEFKUDKSI VFOIDRPDHFCXXGBTML    ---    4
# GHVPEHRLKPIZ AXDBOZE TIMXFUKRW    ---    4
# DAZPMIRZDBICMEJFDYREON DBMDEOY    ---    4
# XEBAZPIRIE YFHGAVOUZJKICGWXCEQ    ---    4
# E POA BSWMYGKYXXLGTDXZ AQJGU Q    ---    6
# AWRAJCHBZE C AMPGQQJMICUDCKCZA    ---    5
# ASIWY JMHWSQLSHCESCNSNVLQGLSBF    ---    4
# ZKSFI GIWLIH QJQLAKPVDUMANTUGL    ---    4
# MEDELHIOMVTXDOUD RDHQQ DKDINLB    ---    4
# AVRHOSRRMGJIB HWMOXTKTWYWWUCIM    ---    4
# GJZZUUWVY TO CHILM QSTIMBPIOZU    ---    5
# ULPJTXWISWZEOPKEDJXAVUFCJUDA L    ---    4
# HXKSGXXODBZFGLKLJVIMFFIHEGKHCE    ---    4
# ASWGA I WXBYYUPH XHQZOQDTSMV L    ---    4
# JMJUAFTCNAZ BLUEKBWCUT PGJDVJS    ---    4
# LKADP XQDEJBXC PYDVNDEBUEGTDAO    ---    4
# KTZUWSIO BZGLLUVNAKESCHLJENALT    ---    4
# CYXYZEUUDSCGFVOGVTTETDGL UDSRS    ---    4
# YKYPESZAD RTJVOJXBUYSVYKHPZCAL    ---    4
# SWZFG OGCOKQRMOEYILMSQTU PSYHK    ---    4
# LHPKD OEPKFINFLZAMZTWJMMKXJJQK    ---    4
# AEDKAIKLFEYJPUBMJHZYUXRO  ZPFK    ---    4
# ETBMBUXBWHE WGOKRBSEZOMGS BC Q    ---    4
# AYUNYKCVFSPBZDFAVXVVQNZJARRRTJ    ---    4
# NCYVVAWMNFPXILUBDSJVCEHECVJCZH    ---    4
# CWOGVDNBQEDYTQXYSTBISTZJHGUKWT    ---    4
# OLKNRUIADHPMNZZKDMV KNXKMZREJK    ---    4
# CLLNAVBVJITXQDLAZ CNVHOWZHLNYE    ---    5
# XKKWR X IFZZTJSWDUOZSMLQPVICCJ    ---    5
# USYUOMTVIK RYQDPT  EZYAMZSXPAZ    ---    4
# LLAWZAOXTAWZBROZSLQPQK XVBIVT     ---    4
# LLMYONXOQETXNQDWJGINVCMEE  AQN    ---    4
# QMPIUUCQJNOIWTXAPAOCGKIISGJZHA    ---    4
#  MGHGICOKQDEXMBNN VIARYHBMVHBO    ---    4
# QIJLKGCOIRYXQBJOL BQDEWEXSJZDI    ---    4
# AFPMKYVWHSLEPAONSFHPANIRZOHZ C    ---    4
# SUPGDYQVEPCG MFANDCPGMSSWPOCHE    ---    4
# PTNHAREOQOGYLPFHSKFAHYGILARB Q    ---    4
# QQFHYDF XHNE AXPVQFPSGCMKYCYVY    ---    4
# AKZCI OLDXAVZLBDAYFTTIK BVAYZU    ---    4
# EGDXB QPQUEXCFJFNDHZKBWMCZUCWQ    ---    4
# WLPEASBHHNAXAWGZZLKPYKHXSKZMEQ    ---    4
# BSH ILEUCNOX LYBAGEVKT GVIVNPW    ---    5
# ZHZWBKCKVPJVHLODL AAMJQBCVLLC     ---    4
# AU QYNHRGSN ZLVA  ZQVFPUWRHEBW    ---    4
# SXMFVDQQDE NIADBFSDHRTNIUGSLQY    ---    5
# WLYHEICXIKTCYGZMXPSHMZDVYGWLM     ---    4
# RADQDZWOEPQOZMIZSLJ C GFBGACZK    ---    4
# XSGECKCOINQBW I CLSMSPAZHCER R    ---    4
# GQBLAUHOQMDY AENDWNPWYUYPSZDXB    ---    4
# PLQHV KPABWZKNOFTABHXHCGVA LND    ---    4
# YU AYHJOYQ BFFSOOATJRTRLRGVZMX    ---    5
# DDDWBAPMROVX BGRB ZT SDTLONCNA    ---    4
# AEIPRCTBXVRXJGXGXEJSUTVBAIXGFO    ---    4
# FOTMUWSONAGRRLOQUPJUHVLPNGNQCV    ---    4
# KXENWKZQKEWIOMQLB MQX  KVRIPDR    ---    4
# YBJGQLWKDP FXSCMDETMXZLWYRBXVP    ---    4
# YLPDGVMGLZWMUGWBKKRDTE JKKMD U    ---    4
# MMXDKZHDDE EXAUAXPRJNTUJPIJIXU    ---    5
# YSZHTQAXPCVAMPOLQRNKYNXOAGSVWN    ---    4
# DGZEKPFUCERF T VYDLJETMGPYWV V    ---    4
# AWKHQ FWNFSNHLCLSEEOQCSBBRTDK     ---    4
# UBHFSLJHYEDPBC LDMYHNDOGYWIYPK    ---    4
# VMOYIDCUWSHJWLUKGLJTXOIIMGME J    ---    4
# PTSTPZXXDMSUOLOAMKMYBZXTQPILYL    ---    5
# UDHVA XZBICPXVOAN ENON MBBGTCG    ---    7
# SD BVZQEDCORFHEELSDSWTBVPZIU H    ---    4
# KBEOLGCHZZMOCSMGAYNPQZEEVJICTK    ---    4
# MNLPAH ZOEMY PNDBBAICCEQPAIVMX    ---    4
# AMGFM NEJLCMERITPITLFWLXGGGPRN    ---    4
# QLRDUWCDNI P ZFRNBKFMJJKTHXDYI    ---    4
# B PHBFLPUSSIFZQCZ VHUTWTZMZLUR    ---    4
# BIPRSVULYTOXASEAWGFGCLGLMGTBGQ    ---    4
# VMBQHNQU DBZ QEFUYWPUB CMGNP      ---    4
# UCGPMTCKCCVGTLZASWWNAXNAERVZJK    ---    4
# AAEZ OQSEEHZZWV AJLEGPHZWGKT O    ---    5
# EJEKC ZZIELWHQXTCOFNSXFK SUHJK    ---    4
# VNLXQXAXJEOAQJGCRUIBJWAMKGIWBO    ---    4
# JJZVIVELDB XSKJVPBUXJIIMNNFAGI    ---    4
# FXKPAXVRDAG NZ N QKYBB RTGZAWD    ---    4
# GQPSUSSXDTOXNRUMQUTSVIBFQEQMIC    ---    4
# IZRSFUCRXUBDWPJWQCQERKDOIGDC Z    ---    5
# NAJDRLJOIUQMFLJBTQEPXLGPSOIIGK    ---    4
#  HO CMCOUSFJXYLMJFMEXVRFCHIFDC    ---    4
# BPXVNNALUITWAYKAMETHYPTJIVIL G    ---    4
# K VH JAQGL XAMLTJUZDHLVIYXIFLL    ---    4
# BXZHPWHWFBGFFIYADSVEEADPQ BZBA    ---    4
# VGQHHRBCPHQNMESDTCYFSTFFDUFCIC    ---    4
# ILKELDTWDO FHCWJMPFJSJEEDOSHOE    ---    4
# RZPNQGLOLUWXVWWSRIOODWRMUPUBCV    ---    4
# K FFAAUODEIELKYEXVLGHVTWLYHLUZ    ---    4
# KALHE ZXTT YFLHOOITOMGLYHLLMFT    ---    5
# MYJLABCYBHJIUUGHYLYWLZVMRHMVBK    ---    4
# ODYZZM FKEJTXPFQYWIJKY MP XCCN    ---    4
# IUCXKS  DNEB LNFDNLTPWJKFNF XT    ---    4
# ZRNUHUMYDM QGCOAJJRTOAKPNFVIEP    ---    4
# IXPKDACONJLDPWSOPDGEMUD PKGZPB    ---    4
# M BVKWUKDSMCCYOLDTODCJXGA MEHV    ---    4
# LQW YRQESF UGQSJY QSFV JSFLCN     ---    4
# AYICLNK  FYCYDVYMQGMKQSMAHQCHS    ---    4
# LNTCAOYHDSVTNTOTTQHQ SXJAPCFSI    ---    4
# ISPQL HCVN MMPLAKOABAVIRCARKKU    ---    4
# AGQIQYATJHOWCJ RVXNXLEPZAGDRSK    ---    4
# DGIVMRCPOGVX DJTHOGVQTW FXBXAF    ---    4
# IUESJOLLXZ ZJEOUUVZEHKXODGIUHZ    ---    5
# IVKMTVWCEK WAVOKTEKCKGKVFMIW A    ---    4
# T CDI QZUEHYDDLNDIDX JFMWSTHFG    ---    4
# AVCIXLNPRSDFQUGJ  TWETSDNZZ LD    ---    4
# ASDGZLIOJITBLSXZBUC N  SKZIMFO    ---    4
# AYPWNOQRHCQXV VXNTGUDR BCRAQBP    ---    4
# GLEDHFAGRZCPYBHRFOAVETX AGWVKQ    ---    4
# EOFOIJCWZDTU MMXF TMCSAPGOECJY    ---    5
# WRRPFAQOBWNU LX CM RJAMMAOXPJK    ---    6
# HNPNSSTI MZSFLO GDOEFLCKGXKLOC    ---    4
# DLQOATIPDNQPGTQSHVMGPH LQXAKX     ---    4
# EKPRATYXCN LLSOCCFIMLGHRYLQAN     ---    4
# ATN ZNLMAYRXBN GUMWESVMIPJGGCA    ---    4
# AMKHQDMMHMNSC OAXIX ADBZLJZKPW    ---    4
# UUWFAQPWKEGXWMATMRXUWHBYQEZC R    ---    5
# JBIAPGVGTCHGMLPADKHZS LNGOEP J    ---    5
# URTHAZEWENNJLPMRU DZEOPRATPKAK    ---    5
# ZLVGO QYHMYIKCUBM GVTNAVTWIYTZ    ---    4
# BMGYTHBONRDAHMNLK HXYKWH GLE B    ---    4
# VSHHAKKZBMOFNIUUIHUE HQRNDBCIA    ---    4
# JIOJANKWGAO TAUAQCMMNFLTOGILFU    ---    4
# BRUDAGBLN  GCPIAQEEIEVYMFXYGQI    ---    4
# XQTVIIOTMVDPBTOAZVTUPXWGQGJUJJ    ---    4
# HLNUJNJOYQJSIKNLQESNSZYJWUKS N    ---    4
# RLMKPYQEUNPX ASHLCTWDSIGGDFTLT    ---    4
# MXPVJASIIIVSAQ DDVDADYDH D O K    ---    4
# LXBQBKCFRTISDLOBKJMAWRQDHW CGF    ---    4
# TPDJGCNEWSBX PQFWRNQGNS ONTCHK    ---    4
# NLLMMXNSPECGKEXEDJHNSTMOUIGHCY    ---    5
# WLBRM DPCLLQBDYIRQVUZTOBNEDHLK    ---    4
# WLPAZ MEKMUXF UTKWTFFMCIHKARLT    ---    5
# RLKJPKZECRCYHLBAOHYKEFKDGBZV Z    ---    4
# ALXHLCDONLKAGUXUXAJUMLLFJTTMVZ    ---    4
# BLHVYAJODHJOTPGAHUCAKYP KIYKRG    ---    4
# EPGQLXBOJTLV PFBRYF HTVQOERISK    ---    4
# ORYDNOYBOHKKWQXLVKSEJTBMVG FF     ---    4
# LJIUXZWBBDB  UQADGUEI LBLKFPQT    ---    4
# VLAXTUNGPQJSSCWABIWWSTMTFDCXHE    ---    4
# ACGOHXEZDCZATXU CN OWXQMYYLCNH    ---    4
# IWIAJRCGYIJLYUYUVYARSWOOEGXCRN    ---    4
# WTPHSOFQOKXEHWJEPIBEWO EHIDECX    ---    4
# BCBSEZCVUGVPFPVQUN IJ PJAHII O    ---    4
# ALLYOTMCAFQXEWQGIBROHCHMFLHDTW    ---    4
# ALUNUZVFBIBPXPCAMIXTCBG BFROBK    ---    4
# XLBHU YZHNUINZBATRJPMJROYPHRQK    ---    5
# ZDCEKCCOD EQUZRPFEAZJPSWKDILKB    ---    4

# %%
# 0.9910022494376406
# 0.9635136823691116
# 0.9399516948446739
# 0.916109688300331
# 0.8930641615030981
# 0.8730376847803456
# 0.8516561964591662
# 0.8334634725302184
# 0.8169299536355812
# 0.7997051547937333
# 0.7848299675155039
# 0.771713553922079
# 0.7606251081252523
# 0.7490316477161166
k=0
for i in range(200):    
    copn=Population1()
#    k=copn.cross_pop(psize,cop)
    #print(get_unique(cop))
    #print("before-->",len(cop.arr))
    k=copn.cross_pop(psize,cop,12)
    #print(get_unique(copn))
    #print("after-->",len(cop.arr))
    if k==1:
        print("found")
        break
    del(cop)    
    cop=copn
    gc.collect()
# Out:
# ALPHA CODE X LOAD TEST MAGIC K
# found

# %%
cop.max_fitness()
# Out:
# 29

# %%
copn=Population1()
copn.cross_pop(psize,cop)
print(get_unique(copn))
cop=copn
gc.collect()

# %%
len(cop.arr)

# %%
pop=[Population() for i in range(150)]
pop[0].create_population(psize)

# %%
for i in range(1,100):
    #pop[i].min_fit=4
    print("\n\n\n\nPopulation <---------> ",i,"\n\n\n\n")
    flag=pop[i].cross_pop(psize,pop[i-1])
    #pop[i].cross_connect()
    if flag==1:
        print("\n\n\n\nPopulation <---------> ",i,"\n\n\n\n")
        break
    #pop[i].cross_connect()

# %%
len(pop[3].arr)

# %%
del(pop)
gc.collect()

# %%
x=Population()

# %%
len(x.arr)

# %%
#parr=Population()
#parr.create_population(300)
pop=[Population1() for i in range(150)]
pop[0].create_population(psize)

# %%
pop[1].cross_pop(psize,pop[0])

# %%
len(pop[1].arr)

# %%
pop[1].cross_pop(psize,pop[0])
pop[1].cross_pop(psize,pop[0])
pop[1].cross_pop(psize,pop[0])

# %%
len(pop[1].arr)

# %%
for i in range(1,100):
    #pop[i].min_fit=4
    print("\n\n\n\nPopulation <---------> ",i,"\n\n\n\n")
    flag=pop[i].cross_pop(psize,pop[i-1])
    #pop[i].cross_connect()
    if flag==1:
        print("\n\n\n\nPopulation <---------> ",i,"\n\n\n\n")
        break
    #pop[i].cross_connect()

# %%
del(pop)
import gc
gc.collect()

# %%
arr=[1,2]

# %%
arr+=[3]

# %%
arr

# %%
import sys

# %%
class a:
    def __init__(self):
        self.x=0
class b:
    def __init__(self):
        self.x=0
        self.y=0

# %%
g=gene

# %%
sys.getsizeof(b)

# %%
pickle.dumps(a())

# %%
47-36

# %%
from multiprocessing import Process as mp

# %%
def p(s,a):
    s=a

# %%
s1=""
s2=""
p1=mp(p(s1,"abc"))
p2=mp(p(s2,"bcd"))
p1.start()
p2.start()
p1.join()
p2.join()

# %%
s1

# %%
gfitness_cal("ALPHA CODE X LOAD TEST MAGIC K")
